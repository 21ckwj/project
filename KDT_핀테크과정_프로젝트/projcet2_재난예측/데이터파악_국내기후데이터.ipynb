# %% [markdown]
# # 국내기후데이터 파악하기

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/기상청ASOS관측.csv',index_col=0)
df
# Out:
#      지점 번호 관측지점          시간  평균 기온  최저 기온  최저 기온 시각  최고 기온  최대 기온 시각  \
# 0      105   강릉  1980-01-01    3.0   -0.4       714    7.0    1549.0
# 1      105   강릉  1980-01-02    6.0    3.5       207    8.4    1500.0
# 2      105   강릉  1980-01-03    7.5    4.1      1810   12.8    1330.0
# 3      105   강릉  1980-01-04    4.1   -0.8      2356    6.8    1206.0
# 4      105   강릉  1980-01-05   -0.8   -3.9       746    4.3    1224.0
# ..     ...  ...         ...    ...    ...       ...    ...       ...
# 361    131   청주  2021-12-28   -1.4   -4.5       325    1.7    1453.0
# 362    131   청주  2021-12-29    1.8   -3.0       454    7.0    1448.0
# 363    131   청주  2021-12-30   -1.7   -3.8      2312    1.7    1342.0
# 364    131   청주  2021-12-31   -4.6   -6.2      2340   -0.9    1415.0
# 365    131   청주  2022-01-01   -4.5   -9.9       703    0.6    1525.0
#
#      10분 최다 강수량  10분 최다강수량 시각  ...  0.5m 지중온도  1.0m 지중온도  1.5m 지중온도  \
# 0           NaN           NaN  ...        6.1        9.1       11.4
# 1           NaN           NaN  ...        6.7        9.0       11.1
# 2           NaN           NaN  ...        6.8        9.0       11.0
# 3           NaN           NaN  ...        7.0        9.1       11.0
# 4           NaN           NaN  ...        7.3        9.1       10.8
# ..          ...           ...  ...        ...        ...        ...
# 361         NaN           NaN  ...        NaN        NaN        NaN
# 362         NaN           NaN  ...        NaN        NaN        NaN
# 363         NaN           NaN  ...        NaN        NaN        NaN
# 364         NaN           NaN  ...        NaN        NaN        NaN
# 365         NaN           NaN  ...        NaN        NaN        NaN
#
#      3.0m 지중온도  5.0m 지중온도  합계 대형증발량  합계 소형증발량  9-9강수  \
# 0         15.0       15.4       NaN       0.9    2.6
# 1         14.8       15.5       NaN       1.5    1.4
# 2         14.8       15.3       NaN       2.2    NaN
# 3         14.7       15.5       NaN       1.8    1.5
# 4         14.7       15.4       NaN       2.0    NaN
# ..         ...        ...       ...       ...    ...
# 361        NaN        NaN       0.4       0.6    NaN
# 362        NaN        NaN       1.0       1.5    0.0
# 363        NaN        NaN       1.1       1.5    0.0
# 364        NaN        NaN       1.3       1.8    NaN
# 365        NaN        NaN       0.9       1.3    NaN
#
#                                                   일기현상  안개 계속 시간
# 0                                {비}2218-{비}{강도0}2400-       NaN
# 1    -{비}-{비}{강도0}0300-{비}{강도0}0600-{비}{강도0}0900-{비...       NaN
# 2                                                  NaN       NaN
# 3    {비}1406-{싸락눈}1437-{진눈깨비}1450-{진눈깨비}{강도0}1500-{...       NaN
# 4                                                  NaN       NaN
# ..                                                 ...       ...
# 361  {박무}0010-{박무}{강도0}0300-{박무}{강도1}0600-{박무}{강도2}...       NaN
# 362  {박무}0230-{박무}{강도1}0300-{박무}{강도1}0600-{박무}{강도1}...       NaN
# 363           {눈}1445-{눈}{강도0}1500-1655. {눈}2002-2050.       NaN
# 364                                                NaN       NaN
# 365                                                NaN       NaN
#
# [176586 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['지점 번호', '관측지점', '시간', '평균 기온', '최저 기온', '최저 기온 시각', '최고 기온',
#        '최대 기온 시각', '10분 최다 강수량', '10분 최다강수량 시각', '1시간 최다강수량', '1시간 최다 강수량 시각',
#        'sumRnDur', '일강수량', '최대 순간풍속', '최대 순간 풍속 풍향', '최대 순간풍속 시간', '최대 풍속',
#        '최대 풍속 풍향', '최대 풍속 시각', '평균 풍속', '풍정합', '최대 풍향', '평균 이슬점온도', '최소 상대습도',
#        '평균 상대습도 시각', '평균 상대습도', '평균 증기압', '평균 현지기압', '최고 해면 기압', '최고 해면기압 시각',
#        '최저 해면기압', '최저 해면기압 시각', '평균 해면기압', '가조시간', '합계 일조 시간', '1시간 최다 일사량 시각',
#        '1시간 최다 일사량', '합계 일사', '일 최심신적설', '일 최심신적설 시각', '일 최심적설', '일 최심적설 시각',
#        '합계 3시간 신적설', '평균 전운량', '평균 중하층운량', '평균 지면온도', '최저 초상온도', '평균 5cm 지중온도',
#        '평균10cm 지중온도', '평균 20cm 지중온도', '평균 30cm 지중온도', '0.5m 지중온도', '1.0m 지중온도',
#        '1.5m 지중온도', '3.0m 지중온도', '5.0m 지중온도', '합계 대형증발량', '합계 소형증발량', '9-9강수',
#        '일기현상', '안개 계속 시간'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176586 entries, 0 to 365
# Data columns (total 62 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   지점 번호          176586 non-null  int64
#  1   관측지점           176586 non-null  object
#  2   시간             176586 non-null  object
#  3   평균 기온          176581 non-null  float64
#  4   최저 기온          176584 non-null  float64
#  5   최저 기온 시각       176586 non-null  int64
#  6   최고 기온          176583 non-null  float64
#  7   최대 기온 시각       176584 non-null  float64
#  8   10분 최다 강수량     44432 non-null   float64
#  9   10분 최다강수량 시각   33429 non-null   float64
#  10  1시간 최다강수량      44421 non-null   float64
#  11  1시간 최다 강수량 시각  33543 non-null   float64
#  12  sumRnDur       67858 non-null   float64
#  13  일강수량           70401 non-null   float64
#  14  최대 순간풍속        176561 non-null  float64
#  15  최대 순간 풍속 풍향    176559 non-null  float64
#  16  최대 순간풍속 시간     176561 non-null  float64
#  17  최대 풍속          176571 non-null  float64
#  18  최대 풍속 풍향       176571 non-null  float64
#  19  최대 풍속 시각       176573 non-null  float64
#  20  평균 풍속          176555 non-null  float64
#  21  풍정합            176552 non-null  float64
#  22  최대 풍향          176371 non-null  float64
#  23  평균 이슬점온도       176581 non-null  float64
#  24  최소 상대습도        176581 non-null  float64
#  25  평균 상대습도 시각     176582 non-null  float64
#  26  평균 상대습도        176577 non-null  float64
#  27  평균 증기압         176576 non-null  float64
#  28  평균 현지기압        176572 non-null  float64
#  29  최고 해면 기압       176571 non-null  float64
#  30  최고 해면기압 시각     176578 non-null  float64
#  31  최저 해면기압        176567 non-null  float64
#  32  최저 해면기압 시각     176577 non-null  float64
#  33  평균 해면기압        176573 non-null  float64
#  34  가조시간           176581 non-null  float64
#  35  합계 일조 시간       176490 non-null  float64
#  36  1시간 최다 일사량 시각  147010 non-null  float64
#  37  1시간 최다 일사량     147012 non-null  float64
#  38  합계 일사          152696 non-null  float64
#  39  일 최심신적설        6938 non-null    float64
#  40  일 최심신적설 시각     6586 non-null    float64
#  41  일 최심적설         10878 non-null   float64
#  42  일 최심적설 시각      10725 non-null   float64
#  43  합계 3시간 신적설     6914 non-null    float64
#  44  평균 전운량         170388 non-null  float64
#  45  평균 중하층운량       169981 non-null  float64
#  46  평균 지면온도        176567 non-null  float64
#  47  최저 초상온도        176569 non-null  float64
#  48  평균 5cm 지중온도    133896 non-null  float64
#  49  평균10cm 지중온도    133852 non-null  float64
#  50  평균 20cm 지중온도   133910 non-null  float64
#  51  평균 30cm 지중온도   133899 non-null  float64
#  52  0.5m 지중온도      133906 non-null  float64
#  53  1.0m 지중온도      133910 non-null  float64
#  54  1.5m 지중온도      109605 non-null  float64
#  55  3.0m 지중온도      109603 non-null  float64
#  56  5.0m 지중온도      109596 non-null  float64
#  57  합계 대형증발량       96662 non-null   float64
#  58  합계 소형증발량       142474 non-null  float64
#  59  9-9강수          61584 non-null   float64
#  60  일기현상           114903 non-null  object
#  61  안개 계속 시간       11290 non-null   float64
# dtypes: float64(57), int64(2), object(3)
# memory usage: 84.9+ MB

# %%
# 자외선 데이터

df_u = pd.read_csv('./data/자외선B_일최대값.csv',encoding='cp949')
df_u
# Out:
#               일자  자외선 B 일최고값  Unnamed: 2
# 0     1999-01-01         NaN         NaN
# 1     1999-01-02         NaN         NaN
# 2     1999-01-03         NaN         NaN
# 3     1999-01-04         NaN         NaN
# 4     1999-01-05         NaN         NaN
# ...          ...         ...         ...
# 8029  2020-12-27        0.04         NaN
# 8030  2020-12-28        0.05         NaN
# 8031  2020-12-29        0.03         NaN
# 8032  2020-12-30        0.05         NaN
# 8033  2020-12-31        0.05         NaN
#
# [8034 rows x 3 columns]

# %%
df_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8034 entries, 0 to 8033
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   일자          8034 non-null   object
#  1   자외선 B 일최고값  7604 non-null   float64
#  2   Unnamed: 2  0 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 188.4+ KB

# %%
# df_1 = pd.merge()

# %%
df['관측지점'].unique()
# Out:
# array(['강릉', '춘천', '울릉도', '광주', '대구', '대전', '부산', '서울', '전주', '제주', '청주',
#        '백령도'], dtype=object)

# %%
# 서울,경기도 : 서울
# 강원도 : 강릉, 춘천
# 충청남도 : 대전
# 충청북도 : 청주
# 전라북도 : 전주
# 전라남도 : 광주
# 경상북도 : 대구
# 경상남도 : 부산
# 제주도 : 제주

# %% [markdown]
# ## Nan값 확인하기

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: seaborn in c:\users\21ckw\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: matplotlib in c:\users\21ckw\anaconda3\lib\site-packages (from missingno) (3.4.3)
# Requirement already satisfied: numpy in c:\users\21ckw\anaconda3\lib\site-packages (from missingno) (1.20.3)
# Requirement already satisfied: scipy in c:\users\21ckw\anaconda3\lib\site-packages (from missingno) (1.7.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\21ckw\anaconda3\lib\site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\21ckw\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\21ckw\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\21ckw\anaconda3\lib\site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\21ckw\appdata\roaming\python\python39\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\21ckw\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.1)
# Requirement already satisfied: six in c:\users\21ckw\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\21ckw\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.1

# %%
# 한글폰트
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/Malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %% [markdown]
# ### Nan값 시각화

# %%
import missingno as msno
msno.matrix(df_u,figsize=(5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### isnull()함수 사용해서 확인하기

# %%
df_u[df_u['자외선 B 일최고값'].isnull()][:50] # 인덱스 36,37,38 다음 164 -> 인덱스 39부터 데이터 시작
# Out:
#              일자  자외선 B 일최고값  Unnamed: 2
# 0    1999-01-01         NaN         NaN
# 1    1999-01-02         NaN         NaN
# 2    1999-01-03         NaN         NaN
# 3    1999-01-04         NaN         NaN
# 4    1999-01-05         NaN         NaN
# 5    1999-01-06         NaN         NaN
# 6    1999-01-07         NaN         NaN
# 7    1999-01-08         NaN         NaN
# 8    1999-01-09         NaN         NaN
# 9    1999-01-10         NaN         NaN
# 10   1999-01-11         NaN         NaN
# 11   1999-01-12         NaN         NaN
# 12   1999-01-13         NaN         NaN
# 13   1999-01-14         NaN         NaN
# 14   1999-01-15         NaN         NaN
# 15   1999-01-16         NaN         NaN
# 16   1999-01-17         NaN         NaN
# 17   1999-01-18         NaN         NaN
# 18   1999-01-19         NaN         NaN
# 19   1999-01-20         NaN         NaN
# 20   1999-01-21         NaN         NaN
# 21   1999-01-22         NaN         NaN
# 22   1999-01-23         NaN         NaN
# 23   1999-01-24         NaN         NaN
# 24   1999-01-25         NaN         NaN
# 25   1999-01-26         NaN         NaN
# 26   1999-01-27         NaN         NaN
# 27   1999-01-28         NaN         NaN
# 28   1999-01-29         NaN         NaN
# 29   1999-01-30         NaN         NaN
# 30   1999-01-31         NaN         NaN
# 31   1999-02-01         NaN         NaN
# 32   1999-02-02         NaN         NaN
# 33   1999-02-03         NaN         NaN
# 34   1999-02-04         NaN         NaN
# 35   1999-02-05         NaN         NaN
# 36   1999-02-06         NaN         NaN
# 37   1999-02-07         NaN         NaN
# 38   1999-02-08         NaN         NaN
# 164  1999-06-14         NaN         NaN
# 168  1999-06-18         NaN         NaN
# 169  1999-06-19         NaN         NaN
# 170  1999-06-20         NaN         NaN
# 171  1999-06-21         NaN         NaN
# 172  1999-06-22         NaN         NaN
# 194  1999-07-14         NaN         NaN
# 205  1999-07-25         NaN         NaN
# 269  1999-09-27         NaN         NaN
# 270  1999-09-28         NaN         NaN
# 424  2000-02-29         NaN         NaN
