# %% [markdown]
# # 결과정리2 - 키워드만

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

import warnings 
warnings.filterwarnings('ignore')
import os 
import re
import FinanceDataReader as fdr
import time

pd.set_option('display.max.colwidth', 70)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, f1_score, roc_auc_score ,accuracy_score, precision_score, recall_score, confusion_matrix
import joblib 
from sklearn.preprocessing import MinMaxScaler

rfc = RandomForestClassifier()
xgb = XGBClassifier()
cat = CatBoostClassifier()
models = [rfc,xgb,cat]

# %%
import FinanceDataReader as fdr

# %% [markdown]
# # 함수

# %% [markdown]
# ## 전처리 함수

# %%
df_kospi = pd.read_csv('./data/recent_kospi_list.csv',index_col=0)
# 코드 반환
def corp_code(corp_name):
    code = df_kospi[df_kospi['Name']==corp_name]['Symbol'].iloc[0]
    code = str(code).zfill(6)
    return code

# 주가데이터
def stock_price(code,bgn_date= '2016-01-01',end_date= '2022-03-31'):

    df_p = fdr.DataReader(code,bgn_date,end_date)
    df_p = df_p.reset_index()
    df_p = df_p.rename(columns = {'Date': '날짜'})
    df_p = df_p.set_index('날짜',drop=True)
    
    return df_p

# merge
def merge(df_count,df_p):
    df_merge = pd.merge(df_count,df_p['Close'],left_index=True,right_index=True, how='right')
    return df_merge

from sklearn.preprocessing import MinMaxScaler

def mscaler(df):

    df.index = pd.DatetimeIndex(df.index)
    col_list = df.columns
    scaler = MinMaxScaler()
    df_scaled = df.copy()
    df_scaled[col_list] = scaler.fit_transform(df[col_list])
    
    return df_scaled

def add_target(df_merge,window_size, period_rate):

    earning_lst = []
    for i in range(len(df_merge)-window_size):
        
        earning_rate = (df_merge.iloc[i+window_size,-1]- df_merge.iloc[i,-1])/df_merge.iloc[i,-1]

        if earning_rate >= period_rate:
            earning_lst.append(1)
        else:
            earning_lst.append(0)

    df_model = df_merge.iloc[:-window_size,:]
    df_model['target'] = earning_lst
    
    return df_model

def feature_visualization(save_path,num):
    
    model = joblib.load(save_path)
    # 배열형태로 반환
    ft_importance_values = model.feature_importances_

    # 정렬과 시각화를 쉽게 하기 위해 series 전환
    ft_series = pd.Series(ft_importance_values, index = x_test.columns)
    ft_top20 = ft_series.sort_values(ascending=False)[:num]

    # 시각화
    plt.figure(figsize=(8,6))
    plt.title('Feature Importance Top 20')
    sns.barplot(x=ft_top20, y=ft_top20.index)
    plt.show()
    
    return ft_top20

# %% [markdown]
# ## test_result()

# %%
def test_result(month,period_rate):

    window_size = 21*month
    
    if month ==3:
        test_stdate = '2021-07-01'
    else:
        test_stdate = '2021-04-01'

    path = './data/데이터_뉴스키워드빈도/'
    file_list = os.listdir(path)

    models_path = f'./data/machine_model3_{month}개월_{period_rate}/'
    saved_model_list = os.listdir(models_path)
    m_corp_lst =[]
    for save_model in saved_model_list:
        m_corp = save_model.split('_')[0]
        m_corp_lst.append(m_corp)


    corp_list =[]
    model_list = []
    accu_list = []
    precision_list = []
    recall_list = []
    roc_list = []
    model_path_list = []


    for file in file_list[:]:
        corp_name = file[:-4]
        if corp_name in m_corp_lst:
            code = corp_code(corp_name)
            df_p = stock_price(code)

            file_path = os.path.join(path,file)
            df_count = pd.read_csv(file_path,index_col=0)
            df_count.index = pd.DatetimeIndex(df_count.index)
            last_col = df_count.columns[-1]

            df_count = mscaler(df_count)

            df_merge = merge(df_count,df_p)

            df_model = add_target(df_merge,window_size=window_size, period_rate= period_rate)

            x_test = df_model.loc[test_stdate:,:last_col]
            y_test = df_model.loc[test_stdate:,'target']


            for save_model in saved_model_list:
                m_corp = save_model.split('_')[0]
                if m_corp == corp_name:
                    model_path = os.path.join(models_path,save_model)
                    #모델 불러오기
                    model = joblib.load(model_path)
                    model_name = model.__class__.__name__
                    pred = model.predict(x_test)
                    # 결과확인
                    corp_list.append(corp_name)
                    model_list.append(model_name)
                    accuracy = accuracy_score(y_test, pred)
                    accu_list.append(accuracy)

                    proba = model.predict_proba(x_test)[:,1]
                    try:
                        roc_auc = roc_auc_score(y_test, proba)
                    except:
                        roc_auc = 0

                    roc_list.append(roc_auc)

                    precision = precision_score(y_test, pred)
                    precision_list.append(precision)

                    recall = recall_score(y_test, pred)
                    recall_list.append(recall)
                    
                    model_path_list.append(model_path)

    df_result = pd.DataFrame({'회사이름':corp_list, '모델이름':model_list,'accuracy':accu_list,
                      'precision':precision_list,'recall':recall_list,'roc_auc':roc_list,'모델주소':model_path_list})

#     df_result.to_csv(f'./data/model_result_test/machine_model3_{window_size}일_{period_rate}.csv')
    
    return df_result

# %% [markdown]
# # 모델결과 보기

# %% [markdown]
# ## 3개월 5%

# %%
result_3_5 = pd.read_csv('./data/model_result_val/machine_model3_63일_0.05.csv',index_col=0)
result_3_5
# Out:
#        회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0    AJ네트웍스      CatBoostClassifier  0.298387   0.571429  0.045455  0.400884
# 1    CJ CGV  RandomForestClassifier  0.540323   0.560000  0.444444  0.531876
# 2    CJ CGV           XGBClassifier  0.508065   0.527778  0.301587  0.583008
# 3    CJ제일제당  RandomForestClassifier  0.572581   0.615385  0.271186  0.544329
# 4    CJ제일제당           XGBClassifier  0.548387   0.578947  0.186441  0.582790
# ..      ...                     ...       ...        ...       ...       ...
# 440   휠라홀딩스  RandomForestClassifier  0.516129   0.520325  0.984615  0.472099
# 441   휠라홀딩스      CatBoostClassifier  0.524194   0.524590  0.984615  0.484876
# 442     휴스틸  RandomForestClassifier  0.241935   0.666667  0.061856  0.526919
# 443     휴스틸           XGBClassifier  0.233871   0.625000  0.051546  0.533792
# 444     휴스틸      CatBoostClassifier  0.241935   0.714286  0.051546  0.550592
#
#                                                                  모델주소
# 0        ./data/machine_model3_3개월_0.05/AJ네트웍스_CatBoostClassifier.pkl
# 1    ./data/machine_model3_3개월_0.05/CJ CGV_RandomForestClassifier.pkl
# 2             ./data/machine_model3_3개월_0.05/CJ CGV_XGBClassifier.pkl
# 3    ./data/machine_model3_3개월_0.05/CJ제일제당_RandomForestClassifier.pkl
# 4             ./data/machine_model3_3개월_0.05/CJ제일제당_XGBClassifier.pkl
# ..                                                                ...
# 440   ./data/machine_model3_3개월_0.05/휠라홀딩스_RandomForestClassifier.pkl
# 441       ./data/machine_model3_3개월_0.05/휠라홀딩스_CatBoostClassifier.pkl
# 442     ./data/machine_model3_3개월_0.05/휴스틸_RandomForestClassifier.pkl
# 443              ./data/machine_model3_3개월_0.05/휴스틸_XGBClassifier.pkl
# 444         ./data/machine_model3_3개월_0.05/휴스틸_CatBoostClassifier.pkl
#
# [445 rows x 7 columns]

# %%
month = 3
window_size = 21*month
period_rate= 0.05

path = './data/데이터_뉴스키워드빈도/'
file_list = os.listdir(path)

models_path = './data/machine_model3_3개월_0.05/'
saved_model_list = os.listdir(models_path)
m_corp_lst =[]
for save_model in saved_model_list:
    m_corp = save_model.split('_')[0]
    m_corp_lst.append(m_corp)
    

corp_list =[]
model_list = []
accu_list = []
precision_list = []
recall_list = []
roc_list = []
model_path = []

    
for file in file_list[:]:
    corp_name = file[:-4]
    if corp_name in m_corp_lst:
        code = corp_code(corp_name)
        df_p = stock_price(code)

        file_path = os.path.join(path,file)
        df_count = pd.read_csv(file_path,index_col=0)
        df_count.index = pd.DatetimeIndex(df_count.index)
        last_col = df_count.columns[-1]

        df_count = mscaler(df_count)

        df_merge = merge(df_count,df_p)

        df_model = add_target(df_merge,window_size=window_size, period_rate= period_rate)

        x_train = df_model.loc['2016-05-02':'2020-12-31',:last_col]
        y_train = df_model.loc['2016-05-02':'2020-12-31','target']

        x_val = df_model.loc['2021-01-04':'2021-07-01',:last_col]
        y_val = df_model.loc['2021-01-04':'2021-07-01','target']

        x_test = df_model.loc['2021-07-01':,:last_col]
        y_test = df_model.loc['2021-07-01':,'target']
        

        for save_model in saved_model_list:
            m_corp = save_model.split('_')[0]
            if m_corp == corp_name:
                print(m_corp)
                model_path = os.path.join(models_path,save_model)
                #모델 불러오기
                model = joblib.load(model_path)
                model_name = model.__class__.__name__
                pred = model.predict(x_test)
                # 결과확인
                corp_list.append(corp_name)
                model_list.append(model_name)
                accuracy = accuracy_score(y_test, pred)
                accu_list.append(accuracy)
                
                proba = model.predict_proba(x_test)[:,1]
                try:
                    roc_auc = roc_auc_score(y_test, proba)
                except:
                    roc_auc = 0
                    
                roc_list.append(roc_auc)
                
                precision = precision_score(y_test, pred)
                precision_list.append(precision)
                
                recall = recall_score(y_test, pred)
                recall_list.append(recall)
                
df_result = pd.DataFrame({'회사이름':corp_list, '모델이름':model_list,'accuracy':accu_list,
                  'precision':precision_list,'recall':recall_list,'roc_auc':roc_list,'모델주소':model_path})

df_result.to_csv(f'./data/model_result_test/machine_model3_{window_size}일_{period_rate}.csv')
# Out:
# AJ네트웍스
# CJ CGV
# CJ CGV
# CJ제일제당
# CJ제일제당
# DB
# DB
# DB
# DB하이텍
# DB하이텍
# DB하이텍
# DI동일
# DI동일
# DI동일
# DSR
# E1
# GS글로벌
# GS글로벌
# GS글로벌
# HDC
# HDC
# HMM
# HMM
# HMM
# HSD엔진
# KG케미칼
# KG케미칼
# KG케미칼
# KISCO홀딩스
# KISCO홀딩스
# KISCO홀딩스
# KSS해운
# KSS해운
# KT
# KT
# KT
# KTcs
# KTcs
# LG
# LG
# LG유플러스
# LG유플러스
# LG이노텍
# LG이노텍
# LG이노텍
# LIG넥스원
# LIG넥스원
# LIG넥스원
# LS네트웍스
# LS네트웍스
# LS네트웍스
# MH에탄올
# NAVER
# NAVER
# NAVER
# NPC
# NPC
# S-Oil
# S-Oil
# S-Oil
# SBS
# SBS
# SBS
# SGC에너지
# SGC에너지
# SGC에너지
# SG세계물산
# SJM
# SKC
# SKC
# SKC
# SK가스
# SK가스
# SK가스
# SK네트웍스
# SK네트웍스
# SK텔레콤
# SK텔레콤
# SPC삼립
# STX엔진
# STX엔진
# TCC스틸
# 강남제비스코
# 강남제비스코
# 경동나비엔
# 계룡건설
# 계룡건설
# 계룡건설
# 계양전기
# 계양전기
# 고려아연
# 고려아연
# 고려제강
# 광명전기
# 광명전기
# 광명전기
# 광전자
# 광전자
# 국도화학
# 국도화학
# 국도화학
# 금강공업
# 금강공업
# 금강공업
# 금양
# 금양
# 금호건설
# 금호건설
# 금호타이어
# 넥센
# 넥센
# 넥센타이어
# 넥센타이어
# 넥센타이어
# 농심
# 농심
# 대동
# 대동
# 대동
# 대우건설
# 대우건설
# 대우건설
# 대웅제약
# 대원전선
# 대원전선
# 대원전선
# 대원화성
# 대원화성
# 대창
# 대창
# 대창
# 대창단조
# 대창단조
# 대한전선
# 대한전선
# 대한제강
# 대한제강
# 대한제강
# 대한제분
# 대한제분
# 대한항공
# 대한항공
# 대한항공
# 덕성
# 덕성
# 도화엔지니어링
# 동국제강
# 동국제강
# 동국제강
# 동부건설
# 동부건설
# 동부건설
# 동아쏘시오홀딩스
# 동아지질
# 동아지질
# 동양
# 동양
# 동양
# 동양철관
# 동양철관
# 동원F&B
# 동일산업
# 동일산업
# 동일산업
# 두산
# 두산
# 두산
# 디아이씨
# 디아이씨
# 디아이씨
# 롯데관광개발
# 롯데관광개발
# 롯데관광개발
# 롯데정밀화학
# 롯데정밀화학
# 롯데정밀화학
# 롯데칠성
# 롯데칠성
# 롯데칠성
# 모나미
# 무림페이퍼
# 무학
# 무학
# 미원상사
# 미원상사
# 미원상사
# 백산
# 백산
# 범양건영
# 범양건영
# 벽산
# 벽산
# 벽산
# 보령
# 보령
# 비상교육
# 비상교육
# 사조동아원
# 사조동아원
# 사조동아원
# 사조산업
# 사조산업
# 사조산업
# 삼성SDI
# 삼성SDI
# 삼성SDI
# 삼성공조
# 삼성엔지니어링
# 삼성엔지니어링
# 삼성엔지니어링
# 삼성출판사
# 삼성출판사
# 삼성출판사
# 삼양사
# 삼영전자
# 삼영전자
# 삼영전자
# 삼익악기
# 삼천리
# 삼천리
# 삼호개발
# 삼호개발
# 삼호개발
# 삼화전기
# 삼화전기
# 삼화전기
# 서연
# 서연
# 서연
# 서원
# 성신양회
# 성신양회
# 성신양회
# 성안
# 세아제강지주
# 세아제강지주
# 세아제강지주
# 세아홀딩스
# 세아홀딩스
# 세종공업
# 세종공업
# 세종공업
# 세진중공업
# 세진중공업
# 신대양제지
# 신대양제지
# 신대양제지
# 신도리코
# 신세계푸드
# 신원
# 신원
# 신원
# 신흥
# 신흥
# 신흥
# 아모레G
# 아세아
# 아세아
# 아세아
# 아세아시멘트
# 아세아제지
# 아세아제지
# 아세아제지
# 아시아나항공
# 아이마켓코리아
# 아이마켓코리아
# 아이에스동서
# 아이에스동서
# 아이에스동서
# 에넥스
# 에넥스
# 에넥스
# 에스엘
# 에스엘
# 에스엘
# 영원무역
# 영원무역
# 영원무역
# 영원무역홀딩스
# 영풍
# 영풍
# 영풍
# 우성
# 우진
# 우진
# 우진
# 우진플라임
# 우진플라임
# 우진플라임
# 원림
# 원림
# 원림
# 유성기업
# 이건산업
# 이연제약
# 이연제약
# 이연제약
# 인스코비
# 인스코비
# 인스코비
# 인터지스
# 인팩
# 인팩
# 인팩
# 일신방직
# 일진머티리얼즈
# 일진머티리얼즈
# 일진머티리얼즈
# 일진전기
# 일진전기
# 일진전기
# 제이에스코퍼레이션
# 제이준코스메틱
# 제일기획
# 제일기획
# 제일기획
# 제주항공
# 제주항공
# 종근당홀딩스
# 종근당홀딩스
# 진양산업
# 진양산업
# 진양산업
# 진원생명과학
# 진원생명과학
# 진원생명과학
# 카카오
# 카카오
# 카카오
# 코스맥스
# 코스맥스
# 코스맥스
# 코스맥스비티아이
# 코아스
# 코오롱
# 코오롱
# 코오롱
# 코오롱인더
# 코오롱인더
# 코오롱인더
# 코오롱플라스틱
# 코오롱플라스틱
# 코웨이
# 콤텍시스템
# 쿠쿠홀딩스
# 쿠쿠홀딩스
# 쿠쿠홀딩스
# 태경비케이
# 태경비케이
# 태경비케이
# 태경케미컬
# 태경케미컬
# 태경케미컬
# 태평양물산
# 티웨이홀딩스
# 팬오션
# 팬오션
# 팬오션
# 포스코인터내셔널
# 포스코인터내셔널
# 포스코인터내셔널
# 한국가스공사
# 한국가스공사
# 한국공항
# 한국공항
# 한국공항
# 한국단자
# 한국단자
# 한국단자
# 한국석유
# 한국수출포장
# 한국수출포장
# 한국앤컴퍼니
# 한국앤컴퍼니
# 한라홀딩스
# 한라홀딩스
# 한라홀딩스
# 한미반도체
# 한미반도체
# 한미반도체
# 한세실업
# 한세실업
# 한세실업
# 한세엠케이
# 한세엠케이
# 한세엠케이
# 한세예스24홀딩스
# 한세예스24홀딩스
# 한솔로지스틱스
# 한솔로지스틱스
# 한솔로지스틱스
# 한솔제지
# 한솔제지
# 한솔케미칼
# 한솔케미칼
# 한솔케미칼
# 한신공영
# 한신공영
# 한신공영
# 한신기계
# 한익스프레스
# 한익스프레스
# 한익스프레스
# 한전KPS
# 한전KPS
# 한진중공업홀딩스
# 한진칼
# 한화에어로스페이스
# 한화에어로스페이스
# 한화에어로스페이스
# 현대건설
# 현대건설
# 현대건설
# 현대로템
# 현대로템
# 현대로템
# 현대리바트
# 현대리바트
# 현대미포조선
# 현대미포조선
# 현대미포조선
# 현대비앤지스틸
# 현대비앤지스틸
# 현대비앤지스틸
# 현대엘리베이
# 현대엘리베이
# 현대엘리베이
# 현대제철
# 현대제철
# 현대제철
# 호텔신라
# 화신
# 화신
# 화신
# 황금에스티
# 황금에스티
# 황금에스티
# 효성
# 효성
# 효성
# 휠라홀딩스
# 휠라홀딩스
# 휴스틸
# 휴스틸
# 휴스틸

# %%
df_result = test_result(3,0.05)
df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
# Out:
#           회사이름                    모델이름  accuracy  precision    recall  \
# 8        DB하이텍      CatBoostClassifier  0.603306   0.605769  0.900000
# 9        DB하이텍  RandomForestClassifier  0.479339   0.559322  0.471429
# 10       DB하이텍           XGBClassifier  0.462810   0.540984  0.471429
# 24       HSD엔진  RandomForestClassifier  0.495868   0.504348  0.935484
# 42       LG이노텍      CatBoostClassifier  0.603306   0.750000  0.734043
# 43       LG이노텍  RandomForestClassifier  0.545455   0.760000  0.606383
# 44       LG이노텍           XGBClassifier  0.561983   0.746988  0.659574
# 76       SK텔레콤      CatBoostClassifier  0.611570   0.529412  0.187500
# 81       TCC스틸           XGBClassifier  0.305785   0.619048  0.146067
# 96         광전자      CatBoostClassifier  0.545455   0.750000  0.101695
# 97         광전자  RandomForestClassifier  0.528926   0.666667  0.067797
# 164         두산      CatBoostClassifier  0.471074   0.509804  0.400000
# 165         두산  RandomForestClassifier  0.487603   0.516854  0.707692
# 166         두산           XGBClassifier  0.586777   0.636364  0.538462
# 176       롯데칠성      CatBoostClassifier  0.570248   0.568182  0.431034
# 178       롯데칠성           XGBClassifier  0.561983   0.564103  0.379310
# 186         백산  RandomForestClassifier  0.520661   0.571429  0.067797
# 187         백산           XGBClassifier  0.545455   0.666667  0.135593
# 199      사조동아원           XGBClassifier  0.809917   0.750000  0.120000
# 250         신원  RandomForestClassifier  0.586777   0.560000  0.264151
# 251         신원           XGBClassifier  0.603306   0.600000  0.283019
# 276       영원무역  RandomForestClassifier  0.512397   0.535714  0.245902
# 304       일신방직      CatBoostClassifier  0.462810   0.600000  0.045455
# 305    일진머티리얼즈      CatBoostClassifier  0.446281   0.513889  0.536232
# 306    일진머티리얼즈  RandomForestClassifier  0.537190   0.574713  0.724638
# 322       진양산업           XGBClassifier  0.115702   0.714286  0.045455
# 369       한국석유  RandomForestClassifier  0.611570   0.545455  0.125000
# 374      한라홀딩스      CatBoostClassifier  0.702479   0.600000  0.081081
# 380       한세실업      CatBoostClassifier  0.520661   0.545455  0.101695
# 407  한화에어로스페이스      CatBoostClassifier  0.661157   0.666667  0.177778
# 408  한화에어로스페이스  RandomForestClassifier  0.661157   0.642857  0.200000
#
#       roc_auc  \
# 8    0.477871
# 9    0.464986
# 10   0.463725
# 24   0.494806
# 42   0.475374
# 43   0.500197
# 44   0.455871
# 76   0.466039
# 81   0.459621
# 96   0.528431
# 97   0.498907
# 164  0.502473
# 165  0.547940
# 166  0.588736
# 176  0.548714
# 178  0.568966
# 186  0.522417
# 187  0.547430
# 199  0.627917
# 250  0.581992
# 251  0.635960
# 276  0.505191
# 304  0.520937
# 305  0.397854
# 306  0.406215
# 322  0.440909
# 369  0.534960
# 374  0.589768
# 380  0.556588
# 407  0.466959
# 408  0.549708
#
#                                                                     모델주소
# 8            ./data/machine_model3_3개월_0.05/DB하이텍_CatBoostClassifier.pkl
# 9        ./data/machine_model3_3개월_0.05/DB하이텍_RandomForestClassifier.pkl
# 10                ./data/machine_model3_3개월_0.05/DB하이텍_XGBClassifier.pkl
# 24       ./data/machine_model3_3개월_0.05/HSD엔진_RandomForestClassifier.pkl
# 42           ./data/machine_model3_3개월_0.05/LG이노텍_CatBoostClassifier.pkl
# 43       ./data/machine_model3_3개월_0.05/LG이노텍_RandomForestClassifier.pkl
# 44                ./data/machine_model3_3개월_0.05/LG이노텍_XGBClassifier.pkl
# 76           ./data/machine_model3_3개월_0.05/SK텔레콤_CatBoostClassifier.pkl
# 81                ./data/machine_model3_3개월_0.05/TCC스틸_XGBClassifier.pkl
# 96             ./data/machine_model3_3개월_0.05/광전자_CatBoostClassifier.pkl
# 97         ./data/machine_model3_3개월_0.05/광전자_RandomForestClassifier.pkl
# 164             ./data/machine_model3_3개월_0.05/두산_CatBoostClassifier.pkl
# 165         ./data/machine_model3_3개월_0.05/두산_RandomForestClassifier.pkl
# 166                  ./data/machine_model3_3개월_0.05/두산_XGBClassifier.pkl
# 176           ./data/machine_model3_3개월_0.05/롯데칠성_CatBoostClassifier.pkl
# 178                ./data/machine_model3_3개월_0.05/롯데칠성_XGBClassifier.pkl
# 186         ./data/machine_model3_3개월_0.05/백산_RandomForestClassifier.pkl
# 187                  ./data/machine_model3_3개월_0.05/백산_XGBClassifier.pkl
# 199               ./data/machine_model3_3개월_0.05/사조동아원_XGBClassifier.pkl
# 250         ./data/machine_model3_3개월_0.05/신원_RandomForestClassifier.pkl
# 251                  ./data/machine_model3_3개월_0.05/신원_XGBClassifier.pkl
# 276       ./data/machine_model3_3개월_0.05/영원무역_RandomForestClassifier.pkl
# 304           ./data/machine_model3_3개월_0.05/일신방직_CatBoostClassifier.pkl
# 305        ./data/machine_model3_3개월_0.05/일진머티리얼즈_CatBoostClassifier.pkl
# 306    ./data/machine_model3_3개월_0.05/일진머티리얼즈_RandomForestClassifier.pkl
# 322                ./data/machine_model3_3개월_0.05/진양산업_XGBClassifier.pkl
# 369       ./data/machine_model3_3개월_0.05/한국석유_RandomForestClassifier.pkl
# 374          ./data/machine_model3_3개월_0.05/한라홀딩스_CatBoostClassifier.pkl
# 380           ./data/machine_model3_3개월_0.05/한세실업_CatBoostClassifier.pkl
# 407      ./data/machine_model3_3개월_0.05/한화에어로스페이스_CatBoostClassifier.pkl
# 408  ./data/machine_model3_3개월_0.05/한화에어로스페이스_RandomForestClassifier.pkl

# %%
df_result.to_csv(f'./data/model_result_test/machine_model3_63일_0.05.csv')

# %% [markdown]
# ## 3개월 10%

# %%
result_3_10 = pd.read_csv('./data/model_result_val/machine_model3_63일_0.1.csv',index_col=0)
result_3_10
# Out:
#        회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0    AJ네트웍스  RandomForestClassifier  0.379032   0.666667  0.050633  0.411533
# 1        DB  RandomForestClassifier  0.524194   0.578947  0.619718  0.489636
# 2        DB           XGBClassifier  0.564516   0.626866  0.591549  0.550757
# 3        DB      CatBoostClassifier  0.508065   0.569444  0.577465  0.458278
# 4        E1  RandomForestClassifier  0.306452   0.700000  0.077778  0.395752
# ..      ...                     ...       ...        ...       ...       ...
# 243      효성      CatBoostClassifier  0.298387   0.852941  0.261261  0.448371
# 244   휠라홀딩스  RandomForestClassifier  0.508065   0.538462  0.222222  0.513271
# 245     휴스틸  RandomForestClassifier  0.258065   0.750000  0.031915  0.489539
# 246     휴스틸           XGBClassifier  0.266129   0.800000  0.042553  0.508688
# 247     휴스틸      CatBoostClassifier  0.258065   0.750000  0.031915  0.567376
#
#                                                                 모델주소
# 0    ./data/machine_model3_3개월_0.1/AJ네트웍스_RandomForestClassifier.pkl
# 1        ./data/machine_model3_3개월_0.1/DB_RandomForestClassifier.pkl
# 2                 ./data/machine_model3_3개월_0.1/DB_XGBClassifier.pkl
# 3            ./data/machine_model3_3개월_0.1/DB_CatBoostClassifier.pkl
# 4        ./data/machine_model3_3개월_0.1/E1_RandomForestClassifier.pkl
# ..                                                               ...
# 243          ./data/machine_model3_3개월_0.1/효성_CatBoostClassifier.pkl
# 244   ./data/machine_model3_3개월_0.1/휠라홀딩스_RandomForestClassifier.pkl
# 245     ./data/machine_model3_3개월_0.1/휴스틸_RandomForestClassifier.pkl
# 246              ./data/machine_model3_3개월_0.1/휴스틸_XGBClassifier.pkl
# 247         ./data/machine_model3_3개월_0.1/휴스틸_CatBoostClassifier.pkl
#
# [248 rows x 7 columns]

# %%
df_result = test_result(3,0.1)
df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
# Out:
#           회사이름                    모델이름  accuracy  precision    recall  \
# 40       노루페인트           XGBClassifier  0.694215   0.600000  0.153846
# 43       대성홀딩스      CatBoostClassifier  0.148760   0.650000  0.119266
# 44       대성홀딩스  RandomForestClassifier  0.148760   0.650000  0.119266
# 45       대성홀딩스           XGBClassifier  0.148760   0.650000  0.119266
# 67          두산  RandomForestClassifier  0.537190   0.509804  0.456140
# 68          두산           XGBClassifier  0.578512   0.578947  0.385965
# 198     한국항공우주           XGBClassifier  0.669421   0.583333  0.166667
# 220  한화에어로스페이스      CatBoostClassifier  0.735537   0.600000  0.176471
# 221  한화에어로스페이스  RandomForestClassifier  0.743802   0.636364  0.205882
#
#       roc_auc  \
# 40   0.573014
# 43   0.266820
# 44   0.279052
# 45   0.276758
# 67   0.543037
# 68   0.635417
# 198  0.463532
# 220  0.534145
# 221  0.514875
#
#                                                                    모델주소
# 40                ./data/machine_model3_3개월_0.1/노루페인트_XGBClassifier.pkl
# 43           ./data/machine_model3_3개월_0.1/대성홀딩스_CatBoostClassifier.pkl
# 44       ./data/machine_model3_3개월_0.1/대성홀딩스_RandomForestClassifier.pkl
# 45                ./data/machine_model3_3개월_0.1/대성홀딩스_XGBClassifier.pkl
# 67          ./data/machine_model3_3개월_0.1/두산_RandomForestClassifier.pkl
# 68                   ./data/machine_model3_3개월_0.1/두산_XGBClassifier.pkl
# 198              ./data/machine_model3_3개월_0.1/한국항공우주_XGBClassifier.pkl
# 220      ./data/machine_model3_3개월_0.1/한화에어로스페이스_CatBoostClassifier.pkl
# 221  ./data/machine_model3_3개월_0.1/한화에어로스페이스_RandomForestClassifier.pkl

# %%
df_result.to_csv(f'./data/model_result_test/machine_model3_63일_0.1.csv')

# %% [markdown]
# ## 3개월 15%

# %%
result_3_15 = pd.read_csv('./data/model_result_val/machine_model3_63일_0.15.csv',index_col=0)
result_3_15
# Out:
#        회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0    AJ네트웍스  RandomForestClassifier  0.475806   0.666667  0.030303  0.416928
# 1        DB           XGBClassifier  0.524194   0.508475  0.500000  0.525000
# 2       DSR      CatBoostClassifier  0.435484   0.666667  0.028169  0.531358
# 3        E1      CatBoostClassifier  0.475806   0.800000  0.058824  0.453782
# 4     GS글로벌      CatBoostClassifier  0.588710   0.666667  0.075472  0.632740
# ..      ...                     ...       ...        ...       ...       ...
# 129      효성  RandomForestClassifier  0.379032   0.789474  0.170455  0.556503
# 130      효성           XGBClassifier  0.354839   0.833333  0.113636  0.406408
# 131      효성      CatBoostClassifier  0.298387   0.666667  0.022727  0.420297
# 132     휴스틸           XGBClassifier  0.338710   0.714286  0.058824  0.497436
# 133     휴스틸      CatBoostClassifier  0.322581   0.666667  0.023529  0.548265
#
#                                                                  모델주소
# 0    ./data/machine_model3_3개월_0.15/AJ네트웍스_RandomForestClassifier.pkl
# 1                 ./data/machine_model3_3개월_0.15/DB_XGBClassifier.pkl
# 2           ./data/machine_model3_3개월_0.15/DSR_CatBoostClassifier.pkl
# 3            ./data/machine_model3_3개월_0.15/E1_CatBoostClassifier.pkl
# 4         ./data/machine_model3_3개월_0.15/GS글로벌_CatBoostClassifier.pkl
# ..                                                                ...
# 129      ./data/machine_model3_3개월_0.15/효성_RandomForestClassifier.pkl
# 130               ./data/machine_model3_3개월_0.15/효성_XGBClassifier.pkl
# 131          ./data/machine_model3_3개월_0.15/효성_CatBoostClassifier.pkl
# 132              ./data/machine_model3_3개월_0.15/휴스틸_XGBClassifier.pkl
# 133         ./data/machine_model3_3개월_0.15/휴스틸_CatBoostClassifier.pkl
#
# [134 rows x 7 columns]

# %%
df_result = test_result(3,0.15)
df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
# Out:
#          회사이름                    모델이름  accuracy  precision    recall  \
# 11      LG이노텍      CatBoostClassifier  0.371901   0.750000  0.142857
# 12      LG이노텍  RandomForestClassifier  0.380165   0.800000  0.142857
# 13      LG이노텍           XGBClassifier  0.371901   0.681818  0.178571
# 14     LIG넥스원           XGBClassifier  0.347107   0.750000  0.037037
# 23      TCC스틸           XGBClassifier  0.330579   0.571429  0.048780
# 32       대웅제약  RandomForestClassifier  0.876033   0.666667  0.125000
# 45         두산      CatBoostClassifier  0.603306   0.666667  0.040816
# 46         두산  RandomForestClassifier  0.619835   0.588235  0.204082
# 47         두산           XGBClassifier  0.619835   0.565217  0.265306
# 51   디티알오토모티브      CatBoostClassifier  0.173554   0.666667  0.019802
# 52   디티알오토모티브  RandomForestClassifier  0.173554   0.666667  0.019802
# 89     아세아시멘트           XGBClassifier  0.702479   0.666667  0.054054
# 112    코리아써키트      CatBoostClassifier  0.297521   0.909091  0.106383
# 113    코리아써키트  RandomForestClassifier  0.280992   0.818182  0.095745
# 114    코리아써키트           XGBClassifier  0.247934   0.800000  0.042553
# 145        후성      CatBoostClassifier  0.628099   0.833333  0.102041
#
#       roc_auc  \
# 11   0.457046
# 12   0.456725
# 13   0.487130
# 14   0.560185
# 23   0.436210
# 32   0.607143
# 45   0.480159
# 46   0.486678
# 47   0.609410
# 51   0.491584
# 52   0.471535
# 89   0.534266
# 112  0.454492
# 113  0.474586
# 114  0.453113
# 145  0.592404
#
#                                                                    모델주소
# 11          ./data/machine_model3_3개월_0.15/LG이노텍_CatBoostClassifier.pkl
# 12      ./data/machine_model3_3개월_0.15/LG이노텍_RandomForestClassifier.pkl
# 13               ./data/machine_model3_3개월_0.15/LG이노텍_XGBClassifier.pkl
# 14              ./data/machine_model3_3개월_0.15/LIG넥스원_XGBClassifier.pkl
# 23               ./data/machine_model3_3개월_0.15/TCC스틸_XGBClassifier.pkl
# 32       ./data/machine_model3_3개월_0.15/대웅제약_RandomForestClassifier.pkl
# 45             ./data/machine_model3_3개월_0.15/두산_CatBoostClassifier.pkl
# 46         ./data/machine_model3_3개월_0.15/두산_RandomForestClassifier.pkl
# 47                  ./data/machine_model3_3개월_0.15/두산_XGBClassifier.pkl
# 51       ./data/machine_model3_3개월_0.15/디티알오토모티브_CatBoostClassifier.pkl
# 52   ./data/machine_model3_3개월_0.15/디티알오토모티브_RandomForestClassifier.pkl
# 89              ./data/machine_model3_3개월_0.15/아세아시멘트_XGBClassifier.pkl
# 112        ./data/machine_model3_3개월_0.15/코리아써키트_CatBoostClassifier.pkl
# 113    ./data/machine_model3_3개월_0.15/코리아써키트_RandomForestClassifier.pkl
# 114             ./data/machine_model3_3개월_0.15/코리아써키트_XGBClassifier.pkl
# 145            ./data/machine_model3_3개월_0.15/후성_CatBoostClassifier.pkl

# %%
df_result.to_csv(f'./data/model_result_test/machine_model3_63일_0.15.csv')

# %% [markdown]
# ## 6개월 5%

# %%
result_6_5 = pd.read_csv('./data/model_result_val/machine_model3_126일_0.05.csv',index_col=0)
result_6_5
# Out:
#        회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0       BGF  RandomForestClassifier  0.583333   0.555556  0.535714  0.641741
# 1       BGF           XGBClassifier  0.650000   0.666667  0.500000  0.583705
# 2       BGF      CatBoostClassifier  0.616667   0.600000  0.535714  0.615513
# 3    CJ CGV  RandomForestClassifier  0.483333   0.703704  0.452381  0.517857
# 4    CJ CGV           XGBClassifier  0.483333   0.739130  0.404762  0.650794
# ..      ...                     ...       ...        ...       ...       ...
# 297   효성ITX           XGBClassifier  0.450000   0.666667  0.058824  0.484163
# 298   효성ITX      CatBoostClassifier  0.466667   0.750000  0.088235  0.514706
# 299      후성  RandomForestClassifier  0.716667   0.829268  0.772727  0.784801
# 300      후성           XGBClassifier  0.766667   0.916667  0.750000  0.803267
# 301      후성      CatBoostClassifier  0.383333   0.888889  0.181818  0.742188
#
#                                                                  모델주소
# 0       ./data/machine_model3_6개월_0.05/BGF_RandomForestClassifier.pkl
# 1                ./data/machine_model3_6개월_0.05/BGF_XGBClassifier.pkl
# 2           ./data/machine_model3_6개월_0.05/BGF_CatBoostClassifier.pkl
# 3    ./data/machine_model3_6개월_0.05/CJ CGV_RandomForestClassifier.pkl
# 4             ./data/machine_model3_6개월_0.05/CJ CGV_XGBClassifier.pkl
# ..                                                                ...
# 297            ./data/machine_model3_6개월_0.05/효성ITX_XGBClassifier.pkl
# 298       ./data/machine_model3_6개월_0.05/효성ITX_CatBoostClassifier.pkl
# 299      ./data/machine_model3_6개월_0.05/후성_RandomForestClassifier.pkl
# 300               ./data/machine_model3_6개월_0.05/후성_XGBClassifier.pkl
# 301          ./data/machine_model3_6개월_0.05/후성_CatBoostClassifier.pkl
#
# [302 rows x 7 columns]

# %%
df_result = test_result(6,0.05)
df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
# Out:
#         회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 46     TCC스틸      CatBoostClassifier  0.206612   0.960000  0.201681  0.317227
# 47     TCC스틸  RandomForestClassifier  0.264463   0.968750  0.260504  0.338235
# 48     TCC스틸           XGBClassifier  0.264463   0.968750  0.260504  0.321429
# 67      고려아연      CatBoostClassifier  0.231405   0.666667  0.082474  0.452749
# 68      고려아연  RandomForestClassifier  0.305785   0.809524  0.175258  0.408505
# 69      고려아연           XGBClassifier  0.289256   0.739130  0.175258  0.462414
# 102     대한방직      CatBoostClassifier  0.958678   0.966667  0.991453  0.379274
# 103     대한방직  RandomForestClassifier  0.950413   0.966387  0.982906  0.377137
# 104     대한방직           XGBClassifier  0.950413   0.966387  0.982906  0.381410
# 112     동부건설      CatBoostClassifier  0.636364   0.666667  0.580645  0.685621
# 113     동부건설  RandomForestClassifier  0.595041   0.638298  0.483871  0.641881
# 114     동부건설           XGBClassifier  0.611570   0.627119  0.596774  0.683024
# 188     영원무역           XGBClassifier  0.504132   0.520000  0.213115  0.481694
# 196     이수화학      CatBoostClassifier  0.413223   0.700000  0.093333  0.547536
# 197  일진머티리얼즈      CatBoostClassifier  0.900826   0.990909  0.908333  0.366667
# 198  일진머티리얼즈  RandomForestClassifier  0.859504   0.990476  0.866667  0.208333
# 199  일진머티리얼즈           XGBClassifier  0.892562   0.990826  0.900000  0.183333
# 209     진양산업  RandomForestClassifier  0.190083   0.944444  0.149123  0.625313
# 232   한국가스공사      CatBoostClassifier  0.495868   0.605263  0.333333  0.511706
# 233   한국가스공사  RandomForestClassifier  0.512397   0.625000  0.362319  0.532051
# 234   한국가스공사           XGBClassifier  0.479339   0.593750  0.275362  0.475334
# 254     한세실업      CatBoostClassifier  0.512397   0.565217  0.209677  0.607162
# 255     한세실업  RandomForestClassifier  0.528926   0.592593  0.258065  0.581875
# 256     한세실업           XGBClassifier  0.520661   0.576923  0.241935  0.561509
# 299       후성      CatBoostClassifier  0.165289   0.923077  0.107143  0.760913
# 300       후성  RandomForestClassifier  0.661157   0.973333  0.651786  0.818452
# 301       후성           XGBClassifier  0.462810   0.943396  0.446429  0.664683
#
#                                                                   모델주소
# 46         ./data/machine_model3_6개월_0.05/TCC스틸_CatBoostClassifier.pkl
# 47     ./data/machine_model3_6개월_0.05/TCC스틸_RandomForestClassifier.pkl
# 48              ./data/machine_model3_6개월_0.05/TCC스틸_XGBClassifier.pkl
# 67          ./data/machine_model3_6개월_0.05/고려아연_CatBoostClassifier.pkl
# 68      ./data/machine_model3_6개월_0.05/고려아연_RandomForestClassifier.pkl
# 69               ./data/machine_model3_6개월_0.05/고려아연_XGBClassifier.pkl
# 102         ./data/machine_model3_6개월_0.05/대한방직_CatBoostClassifier.pkl
# 103     ./data/machine_model3_6개월_0.05/대한방직_RandomForestClassifier.pkl
# 104              ./data/machine_model3_6개월_0.05/대한방직_XGBClassifier.pkl
# 112         ./data/machine_model3_6개월_0.05/동부건설_CatBoostClassifier.pkl
# 113     ./data/machine_model3_6개월_0.05/동부건설_RandomForestClassifier.pkl
# 114              ./data/machine_model3_6개월_0.05/동부건설_XGBClassifier.pkl
# 188              ./data/machine_model3_6개월_0.05/영원무역_XGBClassifier.pkl
# 196         ./data/machine_model3_6개월_0.05/이수화학_CatBoostClassifier.pkl
# 197      ./data/machine_model3_6개월_0.05/일진머티리얼즈_CatBoostClassifier.pkl
# 198  ./data/machine_model3_6개월_0.05/일진머티리얼즈_RandomForestClassifier.pkl
# 199           ./data/machine_model3_6개월_0.05/일진머티리얼즈_XGBClassifier.pkl
# 209     ./data/machine_model3_6개월_0.05/진양산업_RandomForestClassifier.pkl
# 232       ./data/machine_model3_6개월_0.05/한국가스공사_CatBoostClassifier.pkl
# 233   ./data/machine_model3_6개월_0.05/한국가스공사_RandomForestClassifier.pkl
# 234            ./data/machine_model3_6개월_0.05/한국가스공사_XGBClassifier.pkl
# 254         ./data/machine_model3_6개월_0.05/한세실업_CatBoostClassifier.pkl
# 255     ./data/machine_model3_6개월_0.05/한세실업_RandomForestClassifier.pkl
# 256              ./data/machine_model3_6개월_0.05/한세실업_XGBClassifier.pkl
# 299           ./data/machine_model3_6개월_0.05/후성_CatBoostClassifier.pkl
# 300       ./data/machine_model3_6개월_0.05/후성_RandomForestClassifier.pkl
# 301                ./data/machine_model3_6개월_0.05/후성_XGBClassifier.pkl

# %%
df_result.to_csv(f'./data/model_result_test/machine_model3_126일_0.05.csv')

# %% [markdown]
# ## 6개월 10%

# %%
result_6_10 = pd.read_csv('./data/model_result_val/machine_model3_126일_0.1.csv',index_col=0)
result_6_10
# Out:
#       회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0      BYC  RandomForestClassifier  0.133333   0.833333  0.089286  0.294643
# 1      BYC      CatBoostClassifier  0.116667   0.714286  0.089286  0.294643
# 2       DB           XGBClassifier  0.833333   0.980392  0.847458  0.830508
# 3     DI동일  RandomForestClassifier  0.416667   0.960000  0.413793  0.448276
# 4     DI동일           XGBClassifier  0.416667   0.960000  0.413793  0.387931
# ..     ...                     ...       ...        ...       ...       ...
# 186     혜인           XGBClassifier  0.566667   0.714286  0.172414  0.633482
# 187     혜인      CatBoostClassifier  0.533333   0.555556  0.172414  0.615128
# 188  황금에스티  RandomForestClassifier  0.066667   0.666667  0.035088  0.327485
# 189  황금에스티      CatBoostClassifier  0.066667   0.666667  0.035088  0.327485
# 190     후성           XGBClassifier  0.400000   0.750000  0.078947  0.595694
#
#                                                                모델주소
# 0      ./data/machine_model3_6개월_0.1/BYC_RandomForestClassifier.pkl
# 1          ./data/machine_model3_6개월_0.1/BYC_CatBoostClassifier.pkl
# 2                ./data/machine_model3_6개월_0.1/DB_XGBClassifier.pkl
# 3     ./data/machine_model3_6개월_0.1/DI동일_RandomForestClassifier.pkl
# 4              ./data/machine_model3_6개월_0.1/DI동일_XGBClassifier.pkl
# ..                                                              ...
# 186              ./data/machine_model3_6개월_0.1/혜인_XGBClassifier.pkl
# 187         ./data/machine_model3_6개월_0.1/혜인_CatBoostClassifier.pkl
# 188  ./data/machine_model3_6개월_0.1/황금에스티_RandomForestClassifier.pkl
# 189      ./data/machine_model3_6개월_0.1/황금에스티_CatBoostClassifier.pkl
# 190              ./data/machine_model3_6개월_0.1/후성_XGBClassifier.pkl
#
# [191 rows x 7 columns]

# %%
df_result = test_result(6,0.1)
df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
# Out:
#         회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0        BYC      CatBoostClassifier  0.363636   0.583333  0.088608  0.475889
# 37     TCC스틸      CatBoostClassifier  0.206612   0.956522  0.188034  0.331197
# 38     TCC스틸  RandomForestClassifier  0.206612   0.920000  0.196581  0.339744
# 39     TCC스틸           XGBClassifier  0.190083   0.913043  0.179487  0.326923
# 77      동부건설      CatBoostClassifier  0.661157   0.588235  0.425532  0.589707
# 128     이수화학      CatBoostClassifier  0.487603   0.666667  0.031746  0.529420
# 129     이수화학  RandomForestClassifier  0.487603   0.571429  0.063492  0.532704
# 131  일진머티리얼즈      CatBoostClassifier  0.818182   0.951923  0.853448  0.282759
# 132  일진머티리얼즈  RandomForestClassifier  0.818182   0.951923  0.853448  0.251724
# 133  일진머티리얼즈           XGBClassifier  0.826446   0.952381  0.862069  0.324138
# 140     진양산업      CatBoostClassifier  0.148760   0.909091  0.089286  0.794643
# 141     진양산업  RandomForestClassifier  0.165289   0.923077  0.107143  0.797619
# 142     진양산업           XGBClassifier  0.123967   0.800000  0.071429  0.784226
# 190       후성           XGBClassifier  0.132231   0.833333  0.045872  0.574541
#
#                                                                  모델주소
# 0            ./data/machine_model3_6개월_0.1/BYC_CatBoostClassifier.pkl
# 37         ./data/machine_model3_6개월_0.1/TCC스틸_CatBoostClassifier.pkl
# 38     ./data/machine_model3_6개월_0.1/TCC스틸_RandomForestClassifier.pkl
# 39              ./data/machine_model3_6개월_0.1/TCC스틸_XGBClassifier.pkl
# 77          ./data/machine_model3_6개월_0.1/동부건설_CatBoostClassifier.pkl
# 128         ./data/machine_model3_6개월_0.1/이수화학_CatBoostClassifier.pkl
# 129     ./data/machine_model3_6개월_0.1/이수화학_RandomForestClassifier.pkl
# 131      ./data/machine_model3_6개월_0.1/일진머티리얼즈_CatBoostClassifier.pkl
# 132  ./data/machine_model3_6개월_0.1/일진머티리얼즈_RandomForestClassifier.pkl
# 133           ./data/machine_model3_6개월_0.1/일진머티리얼즈_XGBClassifier.pkl
# 140         ./data/machine_model3_6개월_0.1/진양산업_CatBoostClassifier.pkl
# 141     ./data/machine_model3_6개월_0.1/진양산업_RandomForestClassifier.pkl
# 142              ./data/machine_model3_6개월_0.1/진양산업_XGBClassifier.pkl
# 190                ./data/machine_model3_6개월_0.1/후성_XGBClassifier.pkl

# %%
df_result.to_csv(f'./data/model_result_test/machine_model3_126일_0.1.csv')

# %% [markdown]
# ## 6개월 15%

# %%
result_6_15 = pd.read_csv('./data/model_result_val/machine_model3_126일_0.15.csv',index_col=0)
result_6_15
# Out:
#       회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 0      BYC  RandomForestClassifier  0.150000   0.571429  0.076923  0.352163
# 1      BYC      CatBoostClassifier  0.150000   0.571429  0.076923  0.347356
# 2       DB  RandomForestClassifier  0.833333   0.923077  0.888889  0.500000
# 3       DB           XGBClassifier  0.800000   0.920000  0.851852  0.537037
# 4       DB      CatBoostClassifier  0.833333   0.923077  0.888889  0.478395
# ..     ...                     ...       ...        ...       ...       ...
# 155     혜인  RandomForestClassifier  0.550000   0.538462  0.250000  0.559152
# 156     혜인           XGBClassifier  0.583333   0.714286  0.178571  0.666295
# 157     혜인      CatBoostClassifier  0.550000   0.555556  0.178571  0.608259
# 158  황금에스티  RandomForestClassifier  0.133333   0.666667  0.037736  0.566038
# 159  황금에스티      CatBoostClassifier  0.133333   0.666667  0.037736  0.563342
#
#                                                                 모델주소
# 0      ./data/machine_model3_6개월_0.15/BYC_RandomForestClassifier.pkl
# 1          ./data/machine_model3_6개월_0.15/BYC_CatBoostClassifier.pkl
# 2       ./data/machine_model3_6개월_0.15/DB_RandomForestClassifier.pkl
# 3                ./data/machine_model3_6개월_0.15/DB_XGBClassifier.pkl
# 4           ./data/machine_model3_6개월_0.15/DB_CatBoostClassifier.pkl
# ..                                                               ...
# 155     ./data/machine_model3_6개월_0.15/혜인_RandomForestClassifier.pkl
# 156              ./data/machine_model3_6개월_0.15/혜인_XGBClassifier.pkl
# 157         ./data/machine_model3_6개월_0.15/혜인_CatBoostClassifier.pkl
# 158  ./data/machine_model3_6개월_0.15/황금에스티_RandomForestClassifier.pkl
# 159      ./data/machine_model3_6개월_0.15/황금에스티_CatBoostClassifier.pkl
#
# [160 rows x 7 columns]

# %%
df_result = test_result(6,0.15)
df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
# Out:
#         회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 37     TCC스틸      CatBoostClassifier  0.198347   0.952381  0.172414  0.293103
# 38     TCC스틸  RandomForestClassifier  0.206612   0.916667  0.189655  0.289655
# 39     TCC스틸           XGBClassifier  0.173554   0.863636  0.163793  0.256897
# 112     이수화학  RandomForestClassifier  0.504132   0.571429  0.065574  0.509973
# 116  일진머티리얼즈      CatBoostClassifier  0.528926   0.859649  0.500000  0.531943
# 117  일진머티리얼즈  RandomForestClassifier  0.727273   0.803738  0.877551  0.565439
# 118  일진머티리얼즈           XGBClassifier  0.702479   0.803922  0.836735  0.535936
# 122     진양산업      CatBoostClassifier  0.148760   0.875000  0.064220  0.753823
# 123     진양산업  RandomForestClassifier  0.148760   0.800000  0.073394  0.691131
# 124     진양산업           XGBClassifier  0.140496   0.777778  0.064220  0.758028
#
#                                                                   모델주소
# 37         ./data/machine_model3_6개월_0.15/TCC스틸_CatBoostClassifier.pkl
# 38     ./data/machine_model3_6개월_0.15/TCC스틸_RandomForestClassifier.pkl
# 39              ./data/machine_model3_6개월_0.15/TCC스틸_XGBClassifier.pkl
# 112     ./data/machine_model3_6개월_0.15/이수화학_RandomForestClassifier.pkl
# 116      ./data/machine_model3_6개월_0.15/일진머티리얼즈_CatBoostClassifier.pkl
# 117  ./data/machine_model3_6개월_0.15/일진머티리얼즈_RandomForestClassifier.pkl
# 118           ./data/machine_model3_6개월_0.15/일진머티리얼즈_XGBClassifier.pkl
# 122         ./data/machine_model3_6개월_0.15/진양산업_CatBoostClassifier.pkl
# 123     ./data/machine_model3_6개월_0.15/진양산업_RandomForestClassifier.pkl
# 124              ./data/machine_model3_6개월_0.15/진양산업_XGBClassifier.pkl

# %%
df_result.to_csv(f'./data/model_result_test/machine_model3_126일_0.15.csv')

# %% [markdown]
# # 3월 30일 투자(시현용)

# %%
df_result = pd.read_csv('./data/model_result_test/machine_model3_63일_0.05.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#           회사이름                    모델이름  accuracy  precision    recall  \
# 43       LG이노텍  RandomForestClassifier  0.545455   0.760000  0.606383
# 199      사조동아원           XGBClassifier  0.809917   0.750000  0.120000
# 96         광전자      CatBoostClassifier  0.545455   0.750000  0.101695
# 322       진양산업           XGBClassifier  0.115702   0.714286  0.045455
# 407  한화에어로스페이스      CatBoostClassifier  0.661157   0.666667  0.177778
# 187         백산           XGBClassifier  0.545455   0.666667  0.135593
# 166         두산           XGBClassifier  0.586777   0.636364  0.538462
# 81       TCC스틸           XGBClassifier  0.305785   0.619048  0.146067
# 8        DB하이텍      CatBoostClassifier  0.603306   0.605769  0.900000
# 304       일신방직      CatBoostClassifier  0.462810   0.600000  0.045455
# 251         신원           XGBClassifier  0.603306   0.600000  0.283019
# 374      한라홀딩스      CatBoostClassifier  0.702479   0.600000  0.081081
# 306    일진머티리얼즈  RandomForestClassifier  0.537190   0.574713  0.724638
# 176       롯데칠성      CatBoostClassifier  0.570248   0.568182  0.431034
# 369       한국석유  RandomForestClassifier  0.611570   0.545455  0.125000
# 380       한세실업      CatBoostClassifier  0.520661   0.545455  0.101695
# 276       영원무역  RandomForestClassifier  0.512397   0.535714  0.245902
# 76       SK텔레콤      CatBoostClassifier  0.611570   0.529412  0.187500
# 24       HSD엔진  RandomForestClassifier  0.495868   0.504348  0.935484
#
#       roc_auc  \
# 43   0.500197
# 199  0.627917
# 96   0.528431
# 322  0.440909
# 407  0.466959
# 187  0.547430
# 166  0.588736
# 81   0.459621
# 8    0.477871
# 304  0.520937
# 251  0.635960
# 374  0.589768
# 306  0.406215
# 176  0.548714
# 369  0.534960
# 380  0.556588
# 276  0.505191
# 76   0.466039
# 24   0.494806
#
#                                                                   모델주소
# 43     ./data/machine_model3_3개월_0.05/LG이노텍_RandomForestClassifier.pkl
# 199             ./data/machine_model3_3개월_0.05/사조동아원_XGBClassifier.pkl
# 96           ./data/machine_model3_3개월_0.05/광전자_CatBoostClassifier.pkl
# 322              ./data/machine_model3_3개월_0.05/진양산업_XGBClassifier.pkl
# 407    ./data/machine_model3_3개월_0.05/한화에어로스페이스_CatBoostClassifier.pkl
# 187                ./data/machine_model3_3개월_0.05/백산_XGBClassifier.pkl
# 166                ./data/machine_model3_3개월_0.05/두산_XGBClassifier.pkl
# 81              ./data/machine_model3_3개월_0.05/TCC스틸_XGBClassifier.pkl
# 8          ./data/machine_model3_3개월_0.05/DB하이텍_CatBoostClassifier.pkl
# 304         ./data/machine_model3_3개월_0.05/일신방직_CatBoostClassifier.pkl
# 251                ./data/machine_model3_3개월_0.05/신원_XGBClassifier.pkl
# 374        ./data/machine_model3_3개월_0.05/한라홀딩스_CatBoostClassifier.pkl
# 306  ./data/machine_model3_3개월_0.05/일진머티리얼즈_RandomForestClassifier.pkl
# 176         ./data/machine_model3_3개월_0.05/롯데칠성_CatBoostClassifier.pkl
# 369     ./data/machine_model3_3개월_0.05/한국석유_RandomForestClassifier.pkl
# 380         ./data/machine_model3_3개월_0.05/한세실업_CatBoostClassifier.pkl
# 276     ./data/machine_model3_3개월_0.05/영원무역_RandomForestClassifier.pkl
# 76         ./data/machine_model3_3개월_0.05/SK텔레콤_CatBoostClassifier.pkl
# 24     ./data/machine_model3_3개월_0.05/HSD엔진_RandomForestClassifier.pkl

# %% [markdown]
# ## 투자 종목 반환 함수: text_invest_result

# %%
def text_invest_result(month,period_rate,date):
    
    window_size = month *21
    df_result = pd.read_csv(f'./data/model_result_test/machine_model3_{window_size}일_{period_rate}.csv',index_col=0)
    df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
    df_result = df_result.sort_values(by='precision',ascending=False)
    df_result.drop_duplicates(subset='회사이름',inplace=True)

    # 키워드 데이터
    path = './data/데이터_뉴스키워드빈도/'

    models_path = f'./data/machine_model3_{month}개월_{period_rate}/'
    saved_model_list = os.listdir(models_path)

    a=''
    invest_lst = []
    for corp_name in df_result['회사이름'].tolist():

        code = corp_code(corp_name)
        df_p = stock_price(code)

        file_path = os.path.join(path,corp_name+'.csv')
        df_count = pd.read_csv(file_path,index_col=0)
        df_count.index = pd.DatetimeIndex(df_count.index)
        df_count = mscaler(df_count)
        last_col = df_count.columns[-1]

        df_merge = merge(df_count,df_p)
        # 특정날짜 모델에 넣을 데이터
        x_invest = np.array(df_merge.loc[date, :last_col]).reshape(1,-1)

        model_path = df_result[df_result['회사이름']==corp_name].iloc[0,-1]
        #모델 불러오기
        model = joblib.load(model_path)
        pred = model.predict(x_invest)[0]

        if pred ==1:
            a += corp_name + '\n'
            invest_lst.append(corp_name)

    return a,invest_lst

# %% [markdown]
# ### 3개월 5%

# %%
text_invest_result(3,0.05,'2022-03-30')
# Out:
# ('LG이노텍\n롯데칠성\n영원무역\nHSD엔진\n', ['LG이노텍', '롯데칠성', '영원무역', 'HSD엔진'])

# %%
code = corp_code('LG이노텍')

# %%
df_p = fdr.DataReader(code,'2022-03-30','2022-06')

# %%
df_result = pd.read_csv(f'./data/model_result_test/machine_model3_63일_0.05.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#           회사이름                    모델이름  accuracy  precision    recall  \
# 43       LG이노텍  RandomForestClassifier  0.545455   0.760000  0.606383
# 199      사조동아원           XGBClassifier  0.809917   0.750000  0.120000
# 96         광전자      CatBoostClassifier  0.545455   0.750000  0.101695
# 322       진양산업           XGBClassifier  0.115702   0.714286  0.045455
# 407  한화에어로스페이스      CatBoostClassifier  0.661157   0.666667  0.177778
# 187         백산           XGBClassifier  0.545455   0.666667  0.135593
# 166         두산           XGBClassifier  0.586777   0.636364  0.538462
# 81       TCC스틸           XGBClassifier  0.305785   0.619048  0.146067
# 8        DB하이텍      CatBoostClassifier  0.603306   0.605769  0.900000
# 304       일신방직      CatBoostClassifier  0.462810   0.600000  0.045455
# 251         신원           XGBClassifier  0.603306   0.600000  0.283019
# 374      한라홀딩스      CatBoostClassifier  0.702479   0.600000  0.081081
# 306    일진머티리얼즈  RandomForestClassifier  0.537190   0.574713  0.724638
# 176       롯데칠성      CatBoostClassifier  0.570248   0.568182  0.431034
# 369       한국석유  RandomForestClassifier  0.611570   0.545455  0.125000
# 380       한세실업      CatBoostClassifier  0.520661   0.545455  0.101695
# 276       영원무역  RandomForestClassifier  0.512397   0.535714  0.245902
# 76       SK텔레콤      CatBoostClassifier  0.611570   0.529412  0.187500
# 24       HSD엔진  RandomForestClassifier  0.495868   0.504348  0.935484
#
#       roc_auc  \
# 43   0.500197
# 199  0.627917
# 96   0.528431
# 322  0.440909
# 407  0.466959
# 187  0.547430
# 166  0.588736
# 81   0.459621
# 8    0.477871
# 304  0.520937
# 251  0.635960
# 374  0.589768
# 306  0.406215
# 176  0.548714
# 369  0.534960
# 380  0.556588
# 276  0.505191
# 76   0.466039
# 24   0.494806
#
#                                                                   모델주소
# 43     ./data/machine_model3_3개월_0.05/LG이노텍_RandomForestClassifier.pkl
# 199             ./data/machine_model3_3개월_0.05/사조동아원_XGBClassifier.pkl
# 96           ./data/machine_model3_3개월_0.05/광전자_CatBoostClassifier.pkl
# 322              ./data/machine_model3_3개월_0.05/진양산업_XGBClassifier.pkl
# 407    ./data/machine_model3_3개월_0.05/한화에어로스페이스_CatBoostClassifier.pkl
# 187                ./data/machine_model3_3개월_0.05/백산_XGBClassifier.pkl
# 166                ./data/machine_model3_3개월_0.05/두산_XGBClassifier.pkl
# 81              ./data/machine_model3_3개월_0.05/TCC스틸_XGBClassifier.pkl
# 8          ./data/machine_model3_3개월_0.05/DB하이텍_CatBoostClassifier.pkl
# 304         ./data/machine_model3_3개월_0.05/일신방직_CatBoostClassifier.pkl
# 251                ./data/machine_model3_3개월_0.05/신원_XGBClassifier.pkl
# 374        ./data/machine_model3_3개월_0.05/한라홀딩스_CatBoostClassifier.pkl
# 306  ./data/machine_model3_3개월_0.05/일진머티리얼즈_RandomForestClassifier.pkl
# 176         ./data/machine_model3_3개월_0.05/롯데칠성_CatBoostClassifier.pkl
# 369     ./data/machine_model3_3개월_0.05/한국석유_RandomForestClassifier.pkl
# 380         ./data/machine_model3_3개월_0.05/한세실업_CatBoostClassifier.pkl
# 276     ./data/machine_model3_3개월_0.05/영원무역_RandomForestClassifier.pkl
# 76         ./data/machine_model3_3개월_0.05/SK텔레콤_CatBoostClassifier.pkl
# 24     ./data/machine_model3_3개월_0.05/HSD엔진_RandomForestClassifier.pkl

# %% [markdown]
# ### 3개월 10%

# %%
text_invest_result(3,0.1,'2022-03-30')
# Out:
# '대성홀딩스\n'

# %%
df_result = pd.read_csv(f'./data/model_result_test/machine_model3_63일_0.1.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#           회사이름                    모델이름  accuracy  precision    recall  \
# 43       대성홀딩스      CatBoostClassifier  0.148760   0.650000  0.119266
# 221  한화에어로스페이스  RandomForestClassifier  0.743802   0.636364  0.205882
# 40       노루페인트           XGBClassifier  0.694215   0.600000  0.153846
# 198     한국항공우주           XGBClassifier  0.669421   0.583333  0.166667
# 68          두산           XGBClassifier  0.578512   0.578947  0.385965
#
#       roc_auc  \
# 43   0.266820
# 221  0.514875
# 40   0.573014
# 198  0.463532
# 68   0.635417
#
#                                                                    모델주소
# 43           ./data/machine_model3_3개월_0.1/대성홀딩스_CatBoostClassifier.pkl
# 221  ./data/machine_model3_3개월_0.1/한화에어로스페이스_RandomForestClassifier.pkl
# 40                ./data/machine_model3_3개월_0.1/노루페인트_XGBClassifier.pkl
# 198              ./data/machine_model3_3개월_0.1/한국항공우주_XGBClassifier.pkl
# 68                   ./data/machine_model3_3개월_0.1/두산_XGBClassifier.pkl

# %% [markdown]
# ### 3개월 15%

# %%
df_result = pd.read_csv(f'./data/model_result_test/machine_model3_63일_0.15.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#          회사이름                    모델이름  accuracy  precision    recall  \
# 112    코리아써키트      CatBoostClassifier  0.297521   0.909091  0.106383
# 145        후성      CatBoostClassifier  0.628099   0.833333  0.102041
# 12      LG이노텍  RandomForestClassifier  0.380165   0.800000  0.142857
# 14     LIG넥스원           XGBClassifier  0.347107   0.750000  0.037037
# 32       대웅제약  RandomForestClassifier  0.876033   0.666667  0.125000
# 45         두산      CatBoostClassifier  0.603306   0.666667  0.040816
# 51   디티알오토모티브      CatBoostClassifier  0.173554   0.666667  0.019802
# 89     아세아시멘트           XGBClassifier  0.702479   0.666667  0.054054
# 23      TCC스틸           XGBClassifier  0.330579   0.571429  0.048780
#
#       roc_auc                                                             모델주소
# 112  0.454492     ./data/machine_model3_3개월_0.15/코리아써키트_CatBoostClassifier.pkl
# 145  0.592404         ./data/machine_model3_3개월_0.15/후성_CatBoostClassifier.pkl
# 12   0.456725  ./data/machine_model3_3개월_0.15/LG이노텍_RandomForestClassifier.pkl
# 14   0.560185          ./data/machine_model3_3개월_0.15/LIG넥스원_XGBClassifier.pkl
# 32   0.607143   ./data/machine_model3_3개월_0.15/대웅제약_RandomForestClassifier.pkl
# 45   0.480159         ./data/machine_model3_3개월_0.15/두산_CatBoostClassifier.pkl
# 51   0.491584   ./data/machine_model3_3개월_0.15/디티알오토모티브_CatBoostClassifier.pkl
# 89   0.534266          ./data/machine_model3_3개월_0.15/아세아시멘트_XGBClassifier.pkl
# 23   0.436210           ./data/machine_model3_3개월_0.15/TCC스틸_XGBClassifier.pkl

# %%
text_invest_result(3,0.15,'2022-03-30')
# Out:
# 'LG이노텍\n'

# %% [markdown]
# ### 6개월 5%

# %%
text_invest_result(6,0.05,'2022-03-30')
# Out:
# '일진머티리얼즈\n후성\n대한방직\n진양산업\n한국가스공사\n한세실업\n'

# %%
df_result = pd.read_csv(f'./data/model_result_test/machine_model3_126일_0.05.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#         회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 197  일진머티리얼즈      CatBoostClassifier  0.900826   0.990909  0.908333  0.366667
# 300       후성  RandomForestClassifier  0.661157   0.973333  0.651786  0.818452
# 47     TCC스틸  RandomForestClassifier  0.264463   0.968750  0.260504  0.338235
# 102     대한방직      CatBoostClassifier  0.958678   0.966667  0.991453  0.379274
# 209     진양산업  RandomForestClassifier  0.190083   0.944444  0.149123  0.625313
# 68      고려아연  RandomForestClassifier  0.305785   0.809524  0.175258  0.408505
# 196     이수화학      CatBoostClassifier  0.413223   0.700000  0.093333  0.547536
# 112     동부건설      CatBoostClassifier  0.636364   0.666667  0.580645  0.685621
# 233   한국가스공사  RandomForestClassifier  0.512397   0.625000  0.362319  0.532051
# 255     한세실업  RandomForestClassifier  0.528926   0.592593  0.258065  0.581875
# 188     영원무역           XGBClassifier  0.504132   0.520000  0.213115  0.481694
#
#                                                                  모델주소
# 197     ./data/machine_model3_6개월_0.05/일진머티리얼즈_CatBoostClassifier.pkl
# 300      ./data/machine_model3_6개월_0.05/후성_RandomForestClassifier.pkl
# 47    ./data/machine_model3_6개월_0.05/TCC스틸_RandomForestClassifier.pkl
# 102        ./data/machine_model3_6개월_0.05/대한방직_CatBoostClassifier.pkl
# 209    ./data/machine_model3_6개월_0.05/진양산업_RandomForestClassifier.pkl
# 68     ./data/machine_model3_6개월_0.05/고려아연_RandomForestClassifier.pkl
# 196        ./data/machine_model3_6개월_0.05/이수화학_CatBoostClassifier.pkl
# 112        ./data/machine_model3_6개월_0.05/동부건설_CatBoostClassifier.pkl
# 233  ./data/machine_model3_6개월_0.05/한국가스공사_RandomForestClassifier.pkl
# 255    ./data/machine_model3_6개월_0.05/한세실업_RandomForestClassifier.pkl
# 188             ./data/machine_model3_6개월_0.05/영원무역_XGBClassifier.pkl

# %% [markdown]
# ### 6개월 10%

# %%
text_invest_result(6,0.1,'2022-03-30')
# Out:
# '진양산업\n'

# %%
df_result = pd.read_csv(f'./data/model_result_test/machine_model3_126일_0.1.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#         회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 37     TCC스틸      CatBoostClassifier  0.206612   0.956522  0.188034  0.331197
# 133  일진머티리얼즈           XGBClassifier  0.826446   0.952381  0.862069  0.324138
# 141     진양산업  RandomForestClassifier  0.165289   0.923077  0.107143  0.797619
# 190       후성           XGBClassifier  0.132231   0.833333  0.045872  0.574541
# 128     이수화학      CatBoostClassifier  0.487603   0.666667  0.031746  0.529420
# 77      동부건설      CatBoostClassifier  0.661157   0.588235  0.425532  0.589707
# 0        BYC      CatBoostClassifier  0.363636   0.583333  0.088608  0.475889
#
#                                                               모델주소
# 37      ./data/machine_model3_6개월_0.1/TCC스틸_CatBoostClassifier.pkl
# 133        ./data/machine_model3_6개월_0.1/일진머티리얼즈_XGBClassifier.pkl
# 141  ./data/machine_model3_6개월_0.1/진양산업_RandomForestClassifier.pkl
# 190             ./data/machine_model3_6개월_0.1/후성_XGBClassifier.pkl
# 128      ./data/machine_model3_6개월_0.1/이수화학_CatBoostClassifier.pkl
# 77       ./data/machine_model3_6개월_0.1/동부건설_CatBoostClassifier.pkl
# 0         ./data/machine_model3_6개월_0.1/BYC_CatBoostClassifier.pkl

# %% [markdown]
# ### 6개월 15%

# %%
df_result = pd.read_csv(f'./data/model_result_test/machine_model3_126일_0.15.csv',index_col=0)
df_result = df_result[(df_result['precision']>0.5) &(df_result['precision'] != 1)]
df_result = df_result.sort_values(by='precision',ascending=False)
df_result.drop_duplicates(subset='회사이름',inplace=True)
df_result
# Out:
#         회사이름                    모델이름  accuracy  precision    recall   roc_auc  \
# 37     TCC스틸      CatBoostClassifier  0.198347   0.952381  0.172414  0.293103
# 122     진양산업      CatBoostClassifier  0.148760   0.875000  0.064220  0.753823
# 116  일진머티리얼즈      CatBoostClassifier  0.528926   0.859649  0.500000  0.531943
# 112     이수화학  RandomForestClassifier  0.504132   0.571429  0.065574  0.509973
#
#                                                                모델주소
# 37      ./data/machine_model3_6개월_0.15/TCC스틸_CatBoostClassifier.pkl
# 122      ./data/machine_model3_6개월_0.15/진양산업_CatBoostClassifier.pkl
# 116   ./data/machine_model3_6개월_0.15/일진머티리얼즈_CatBoostClassifier.pkl
# 112  ./data/machine_model3_6개월_0.15/이수화학_RandomForestClassifier.pkl

# %%
text_invest_result(6,0.15,'2022-03-30')
# Out:
# '진양산업\n일진머티리얼즈\n'

# %% [markdown]
# # 모델 성능 확인(2022-01-03)

# %%
text_invest_result(3,0.05,'2022-01-05')
# Out:
# ('한화에어로스페이스\n두산\nTCC스틸\nDB하이텍\n신원\n일진머티리얼즈\n롯데칠성\nHSD엔진\n',
#  ['한화에어로스페이스', '두산', 'TCC스틸', 'DB하이텍', '신원', '일진머티리얼즈', '롯데칠성', 'HSD엔진'])

# %%
text_invest_result(3,0.1,'2022-01-05')
# Out:
# ('한화에어로스페이스\n두산\n', ['한화에어로스페이스', '두산'])

# %%
code = corp_code('LG이노텍')
df_p = fdr.DataReader(code,'2022-03-15','2022-06-30')
df_p = df_p.iloc[0:63,:]
df_p = df_p.iloc[0:63,:]['Close'].to_frame()
df_p
# Out:
#              Close
# Date
# 2022-03-15  341000
# 2022-03-16  362500
# 2022-03-17  370000
# 2022-03-18  382000
# 2022-03-21  405000
# ...            ...
# 2022-06-08  377500
# 2022-06-09  376500
# 2022-06-10  378000
# 2022-06-13  372500
# 2022-06-14  375500
#
# [63 rows x 1 columns]

# %% [markdown]
# ## check_with_BM()

# %%
def check_with_BM(month,period_rate,bgn_date):
    
    _,corp_lst = text_invest_result(month,period_rate,bgn_date)
    
    invest_lst1 = []
    change_lst = []
    for corp in corp_lst:
        # 회사이름
        invest_lst1.append(corp)
        # 회사코드
        code = corp_code(corp)
        
        df_index = fdr.DataReader('KS11',bgn_date)['Close'].to_frame()
        df_index3 = df_index.loc[bgn_date:][:63]
        df_index6 = df_index.loc[bgn_date:][:126]
        
        df_p = fdr.DataReader(code,bgn_date)
        
        try:
            if month ==3:
                df_p = df_p.iloc[0:63,:]['Close'].to_frame()
                sell_date = df_p.index[-1]
#                 print('매도날짜: ',sell_date)
                change = (df_p.iloc[-1,0]-df_p.iloc[0,0])/df_p.iloc[0,0]
                change_lst.append(change)
                BM3 = ((df_index3.iloc[-1]-df_index3.iloc[0])/df_index3.iloc[0]).iloc[0]

                df_BM = pd.DataFrame({'종목명':invest_lst1,'수익률':change_lst})
                df_BM['평균수익률'] = np.mean(df_BM['수익률'])
                df_BM['BM3'] = BM3 
                df_BM['BM대비 수익률'] = df_BM['평균수익률'] - df_BM['BM3']

            else:
                df_p = df_p.iloc[0:126,:]['Close'].to_frame()
                sell_date = df_p.index[-1]
#                 print('매도날짜: ',sell_date)
                change = (df_p.iloc[-1,0]-df_p.iloc[0,0])/df_p.iloc[0,0]
                change_lst.append(change)
                BM6 = ((df_index6.iloc[-1]-df_index6.iloc[0])/df_index6.iloc[0]).iloc[0]

                df_BM = pd.DataFrame({'종목명':invest_lst1,'수익률':change_lst})
                df_BM['평균수익률'] = np.mean(df_BM['수익률'])
                df_BM['BM6'] = BM6 
                df_BM['BM대비 수익률'] = df_BM['평균수익률'] - df_BM['BM6']
                
        except:
            print('선출된 종목이 없습니다.')
            
    
    return df_BM

# %%
text_invest_result(3,0.05,'2022-01-05')
# Out:
# ('한화에어로스페이스\n두산\nTCC스틸\nDB하이텍\n신원\n일진머티리얼즈\n롯데칠성\nHSD엔진\n',
#  ['한화에어로스페이스', '두산', 'TCC스틸', 'DB하이텍', '신원', '일진머티리얼즈', '롯데칠성', 'HSD엔진'])

# %%
check_with_BM(3,0.05,'2022-01-05')
# Out:
#          종목명       수익률     평균수익률       BM3  BM대비 수익률
# 0  한화에어로스페이스 -0.003929 -0.038281 -0.085844  0.047563
# 1         두산 -0.198374 -0.038281 -0.085844  0.047563
# 2      TCC스틸  0.009174 -0.038281 -0.085844  0.047563
# 3      DB하이텍 -0.063172 -0.038281 -0.085844  0.047563
# 4         신원 -0.255556 -0.038281 -0.085844  0.047563
# 5    일진머티리얼즈 -0.165992 -0.038281 -0.085844  0.047563
# 6       롯데칠성  0.362595 -0.038281 -0.085844  0.047563
# 7      HSD엔진  0.009009 -0.038281 -0.085844  0.047563

# %%
check_with_BM(6,0.05,'2022-01-05')
# Out:
#        종목명       수익률     평균수익률       BM6  BM대비 수익률
# 0  일진머티리얼즈 -0.365182 -0.092445 -0.198841  0.106396
# 1    TCC스틸  0.114679 -0.092445 -0.198841  0.106396
# 2     대한방직 -0.003099 -0.092445 -0.198841  0.106396
# 3     영원무역 -0.116178 -0.092445 -0.198841  0.106396

# %%
check_with_BM(3,0.1,'2022-01-05')
# Out:
#          종목명       수익률     평균수익률       BM3  BM대비 수익률
# 0  한화에어로스페이스 -0.003929 -0.101152 -0.085844 -0.015308
# 1         두산 -0.198374 -0.101152 -0.085844 -0.015308

# %%
check_with_BM(6,0.1,'2022-01-05')
# Out:
#        종목명       수익률     평균수익률       BM6  BM대비 수익률
# 0    TCC스틸  0.114679 -0.125252 -0.198841  0.073589
# 1  일진머티리얼즈 -0.365182 -0.125252 -0.198841  0.073589

# %%
text_invest_result(3,0.15,'2022-01-03')
# Out:
# ('TCC스틸\n', ['TCC스틸'])

# %%
check_with_BM(3,0.15,'2022-01-03')
# Out:
#      종목명       수익률     평균수익률       BM3  BM대비 수익률
# 0  TCC스틸  0.014423  0.014423 -0.084898  0.099321

# %%
check_with_BM(6,0.15,'2022-01-03')
# Out:
#      종목명       수익률     평균수익률       BM6  BM대비 수익률
# 0  TCC스틸  0.100962  0.100962 -0.225661  0.326623

# %%
check_with_BM(3,0.15,'2021-12-30')
# Out:
#       종목명       수익률     평균수익률       BM3  BM대비 수익률
# 0  아세아시멘트  0.413934  0.413934 -0.073363  0.487298

# %%
check_with_BM(6,0.15,'2021-12-30')
# Out:
# 매도날짜:  2022-06-23 00:00:00
# 매도날짜:  2022-06-23 00:00:00
#        종목명       수익률     평균수익률      BM6  BM대비 수익률
# 0    TCC스틸  0.182851 -0.149315 -0.22277  0.073455
# 1  일진머티리얼즈 -0.481481 -0.149315 -0.22277  0.073455

# %% [markdown]
# ## 챗봇 추천 성능

# %%
check_with_BM(3,0.15,'2021-12-29')
# Out:
#       종목명       수익률     평균수익률       BM3  BM대비 수익률
# 0  코리아써키트 -0.003236  0.159515 -0.078639  0.238154
# 1  LIG넥스원  0.067847  0.159515 -0.078639  0.238154
# 2  아세아시멘트  0.413934  0.159515 -0.078639  0.238154

# %%
check_with_BM(6,0.15,'2021-12-29')
# Out:
#      종목명       수익률     평균수익률       BM6  BM대비 수익률
# 0  TCC스틸  0.366704  0.366704 -0.209365  0.576069

# %%
# 현대모비스,sk하이닉스
# 유니온,한진
# 한국전자홀딩스,자화전자

# %%
bgn_date = '2022-01-05'
df_index = fdr.DataReader('KS11','2022-01-05')['Close'].to_frame()
df_index3 = df_index.loc[bgn_date:][:63]
df_index6 = df_index.loc[bgn_date:][:126]
BM3 = ((df_index3.iloc[-1]-df_index3.iloc[0])/df_index3.iloc[0]).iloc[0]
BM6 = (df_index6.iloc[-1]-df_index6.iloc[0])/df_index6.iloc[0]
print(BM3)
BM6
# Out:
# -0.08584379665331739
# Close   -0.216539
# dtype: float64

# %%
df_index3['BM3'] = BM3

# %%
np.mean(df_index3['Close'])
# Out:
# 2752.8026984126973

# %% [markdown]
# # 퀀트 모델 성능

# %%
bgn_date =
end_date =

df_index = fdr.DataReader('KS11',bgn_date,end_date)['Close'].to_frame()
corp_lst = []

for corp in corp_lst:
    code = corp_code(corp)
    df_p = fdr.DataReader(code,bgn_date,end_date)
    df_p = df_p.iloc[bgn_date:,:]['Close'].to_frame()
    # sell_date = df_p.index[-1]
    change = (df_p.iloc[-1,0]-df_p.iloc[0,0])/df_p.iloc[0,0]
    change_lst.append(change)
    BM = ((df_index.iloc[-1]-df_index.iloc[0])/df_index.iloc[0]).iloc[0]

    df_BM = pd.DataFrame({'종목명':corp_lst,'수익률':change_lst})
    df_BM['평균수익률'] = np.mean(df_BM['수익률'])
    df_BM['BM'] = BM 
    df_BM['BM대비 수익률'] = df_BM['평균수익률'] - df_BM['BM']

# %%
def BM(bgn_date,end_date,corp_lst):
    df_index = fdr.DataReader('KS11',bgn_date,end_date)['Close'].to_frame()
    
    change_lst = []
    
    for corp in corp_lst:
        code = corp_code(corp)
        df_p = fdr.DataReader(code,bgn_date,end_date)
        df_p = df_p.loc[bgn_date:end_date,:]['Close'].to_frame()
        # sell_date = df_p.index[-1]
        change = (df_p.iloc[-1,0]-df_p.iloc[0,0])/df_p.iloc[0,0]
        change_lst.append(change)
        
        BM = ((df_index.iloc[-1]-df_index.iloc[0])/df_index.iloc[0]).iloc[0]

    df_BM = pd.DataFrame({'종목명':corp_lst,'수익률':change_lst})
    df_BM['평균수익률'] = np.mean(df_BM['수익률'])
    df_BM['BM'] = BM 
    df_BM['BM대비 수익률'] = df_BM['평균수익률'] - df_BM['BM']

    return df_BM

# %%
# 볼린져 밴드
corp_lst = ['조선내화','KISCO홀딩스','삼영무역','쌍용C&E','롯데정밀화학','효성','풍산홀딩스']
df= BM('2022-01-03','2022-04-03',corp_lst)
df

# 볼린져 밴드

# 평균수익률: 5.51% 
# 코스피수익률 : -8.32%
# BM 대비 수익률: 13.83%
# Out:
#         종목명       수익률     평균수익률        BM  BM대비 수익률
# 0      조선내화 -0.004944  0.055102 -0.083285  0.138387
# 1  KISCO홀딩스  0.217993  0.055102 -0.083285  0.138387
# 2      삼영무역 -0.006944  0.055102 -0.083285  0.138387
# 3     쌍용C&E  0.059818  0.055102 -0.083285  0.138387
# 4    롯데정밀화학  0.134247  0.055102 -0.083285  0.138387
# 5        효성 -0.080645  0.055102 -0.083285  0.138387
# 6     풍산홀딩스  0.066190  0.055102 -0.083285  0.138387

# %%
# 마법의 공식
corp_lst =['LX인터내셔널','한솔홀딩스','깨끗한나라','한솔테크닉스','신송홀딩스','미래아이앤지']
df= BM('2022-01-03','2022-04-03',corp_lst)
df

# 마법의 공식

# 평균수익률: 9.51% 
# 코스피수익률 : -8.32%
# BM 대비 수익률: 17.83%
# Out:
#        종목명       수익률     평균수익률        BM  BM대비 수익률
# 0  LX인터내셔널  0.318182  0.095113 -0.083285  0.178398
# 1    한솔홀딩스  0.016878  0.095113 -0.083285  0.178398
# 2    깨끗한나라  0.087010  0.095113 -0.083285  0.178398
# 3   한솔테크닉스 -0.118557  0.095113 -0.083285  0.178398
# 4    신송홀딩스  0.299424  0.095113 -0.083285  0.178398
# 5   미래아이앤지 -0.032258  0.095113 -0.083285  0.178398

# %%
# famma lsv
corp_lst = ['SUN&L','한국프랜지','케이비아이동국실업','세이브존I&C','무림페이퍼']
df= BM('2022-01-03','2022-04-03',corp_lst)
df

# fammal lsv

# 평균수익률: 7.66% 
# 코스피수익률 : -8.32%
# BM 대비 수익률: 13.54%
# Out:
#          종목명       수익률     평균수익률        BM  BM대비 수익률
# 0      SUN&L  0.076621  0.052189 -0.083285  0.135474
# 1      한국프랜지  0.095865  0.052189 -0.083285  0.135474
# 2  케이비아이동국실업 -0.043157  0.052189 -0.083285  0.135474
# 3    세이브존I&C  0.058923  0.052189 -0.083285  0.135474
# 4      무림페이퍼  0.072692  0.052189 -0.083285  0.135474

# %%
# 절대 모멘텀
corp_lst = ['롯데쇼핑','KPX케미칼','신세계푸드','KT&G','TKG휴켐스','애경케미칼']
df= BM('2022-01-03','2022-04-03',corp_lst)
df

# 절대 모멘텀

# 평균수익률: 1.31% 
# 코스피수익률 : -8.32%
# BM 대비 수익률: 9.63%
# Out:
#       종목명       수익률     평균수익률        BM  BM대비 수익률
# 0    롯데쇼핑  0.128472  0.013099 -0.083285  0.096384
# 1  KPX케미칼  0.018762  0.013099 -0.083285  0.096384
# 2   신세계푸드 -0.044118  0.013099 -0.083285  0.096384
# 3    KT&G  0.025316  0.013099 -0.083285  0.096384
# 4  TKG휴켐스 -0.021930  0.013099 -0.083285  0.096384
# 5   애경케미칼 -0.027907  0.013099 -0.083285  0.096384
