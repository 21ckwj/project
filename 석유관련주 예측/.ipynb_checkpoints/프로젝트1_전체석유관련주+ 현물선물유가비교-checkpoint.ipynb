# %% [markdown]
# # 프로젝트 의의:
# 제무제표는 후행지표이기 때문에 선행성을 가진 주가를 예측하는데 사용하기 힘든 부분이 있음<br>
# 제무제표를 확인하여 투자할 수 있는 방법은 고정비가 많이 ~

# %% [markdown]
# # 프로젝트 목표:
# * 상품의 원재료(석유) 비중이 70% 이상인 기업의 주가들을 하나의 지수로 만들어 선행지표인 석유가격을 활용하여<br>
# 딥러닝을 통해 석유지수를 예측해보려함<br>
# * 주가는 대표적인 비정상시계열이므로 단변량으로 추세 예측 불가능. 따라서 석유가격을 사용한 Multivaraible 모델을 <br>
# 사용할 계획
# * 이를 통해 매일매일 수익률을 확인할 수 있는 프로그램 배포까지 진행할 예정

# %% [markdown]
# # 활용 데이터
# * 기간: 현재로부터 최근 5년
# * 종류: 석유 관련 기업 주가 데이터, 두바이유 선물

# %%
# 지수 구하기
# 해야할것 
# 날짜별 비교시점 시가총액합/ 기준시점시가총액 합
# 정유주 별 지수
# 윤활유주 지수
# 석유화학주 지수
# 전체지수

# %% [markdown]
# # Version

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import sklearn
import tensorflow as tf
import tensorflow_probability as tfp
import sys

print
print("python: ", sys.version)
print("pandas: ", pd.__version__)
print("numpy: ", np.__version__)
print("matplotlib: ", matplotlib.__version__)
print("seaborn: ", sns.__version__)
print("sklearn: ", sklearn.__version__)
print("tensorflow: ", tf.__version__)
print("tensorflow_probability: ", tfp.__version__)
# Out:
# python:  3.8.16 (default, Mar  2 2023, 03:18:16) [MSC v.1916 64 bit (AMD64)]
# pandas:  2.0.1
# numpy:  1.23.4
# matplotlib:  3.7.1
# seaborn:  0.12.2
# sklearn:  1.2.2
# tensorflow:  2.5.0
# tensorflow_probability:  0.12.2

# %% [markdown]
# # 석유 관련주 지수화(index)
# finance datareader 모듈을 사용하여 석유 관련주 종목코드를 수집하여<br>
# 네이버 주식에 발행주식수, 유동비율, 액면가 등을 고려하여 하나의 지수를 만들 예정

# %%
import FinanceDataReader as fdr
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
krx_lst = fdr.StockListing('KRX')  # krx_lst = 한국 전체 주식
krx_lst.head(3)
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes
# 0  005930  KR7005930003      삼성전자  KOSPI        71400          2     -900  \
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       599000          1    19000
# 2  000660  KR7000660001    SK하이닉스  KOSPI       108600          2    -1700
#
#    ChagesRatio    Open    High     Low    Volume         Amount
# 0        -1.24   72400   72500   71000  25666087  1840726217336  \
# 1         3.28  581000  604000  581000    610868   363888359000
# 2        -1.54  110000  110900  108500   8166685   891972441357
#
#             Marcap      Stocks MarketId
# 0  426242474070000  5969782550      STK
# 1  140166000000000   234000000      STK
# 2   79061056839000   728002365      STK

# %% [markdown]
# ## 석유 관련 회사 리스트

# %%
company_lst = [
# 정유주
    'S-Oil',
    'GS',
    'SK이노베이션',
    '중앙에너비스',
    '흥구석유',
    
# 석유주(윤활유 비중 높은회사)
    '극동유화',
    '한국쉘석유',
    '미창석유',

# # 석유화학주
    '롯데케미칼',
    '이수화학',
    '한국석유',
    '코프라', # BGF에코머티리얼스
    'KPX케미칼',
    '애경케미칼'
]
company_lst
# Out:
# ['S-Oil',
#  'GS',
#  'SK이노베이션',
#  '중앙에너비스',
#  '흥구석유',
#  '극동유화',
#  '한국쉘석유',
#  '미창석유',
#  '롯데케미칼',
#  '이수화학',
#  '한국석유',
#  '코프라',
#  'KPX케미칼',
#  '애경케미칼']

# %%
# 회사 코드가 반환되지 않는 회사가 존재
codes = krx_lst[krx_lst['Name'].apply(lambda stock: stock in company_lst)]['Code'].to_list()
print("회사 개수: ", len(company_lst))
print("결과값 개수: ",len(codes))
print(codes)
# Out:
# 회사 개수:  14
# 결과값 개수:  13
# ['096770', '010950', '011170', '078930', '161000', '005950', '002960', '025000', '004090', '014530', '003650', '000440', '024060']

# %%
krx_lst[krx_lst['Name']=='S-Oil'][['Code']]
# Out:
#       Code
# 47  010950

# %%
# 코드 반환 안되는 회사 찾기
for company in company_lst:
    code = krx_lst[krx_lst['Name']==company][['Code']]
    if len(code)==0:
        print(company)
# Out:
# 코프라

# %%
def company_name_to_code(krx_list, company_list):
    """
    회사명 리스트를 넣었을 때 
    회사 코드를 반환해주는 함수
    """
    codes = krx_list[krx_list['Name'].apply(lambda stock: stock in company_lst)]['Code'].to_list()

    # 코드 반환 안되는 회사 찾기
    if len(codes) != len(company_list):
        print("코드 검색이 안된 회사가 있습니다.")
        for company in company_lst:
            code = krx_list[krx_list['Name']==company][['Code']]
            if len(code)==0:
                print(f"{company} 회사명을 확인해보세요")
            
    return codes

codes = company_name_to_code(krx_lst , company_lst)
print(codes)
# Out:
# 코드 검색이 안된 회사가 있습니다.
# 코프라 회사명을 확인해보세요
# ['096770', '010950', '011170', '078930', '161000', '005950', '002960', '025000', '004090', '014530', '003650', '000440', '024060']

# %% [markdown]
# ## 시가총액 구하기

# %%
# 회사별 정보 모으기

driver = webdriver.Chrome()
start_date =  "2017-01-02" 
end_date = "2023-01-02" 

for code in codes:
    df = fdr.DataReader(code,start_date,end_date)
    
    company_name = krx_lst[krx_lst['Code']==code]['Name'].iloc[0]
    print("-"*50)
    print("회사이름: ", company_name)
    #기준시점 시가 총액
    price1 = df.loc[start_date]['Close']
    
    url1 = 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd={}'.format(code)
    driver.get(url1)
    time.sleep(0.5)
    html1 = driver.page_source
    df1 = pd.read_html(html1)[1]
   
    # 발행 주식수
    outstanding = df1.iloc[6][1].split('/')[0]
    outstanding = outstanding.replace('주','') # 1,231,000주 -> 1,231,000
    outstanding = outstanding.replace(',', '') # 1,231,000 -> 1231000
    outstanding =  float(outstanding)
    print("발행 주식수: ",outstanding)
    
    # 유동비율 
    floating = df1.iloc[6][1].split('/')[1]
    floating = floating.replace('%', '')  # %기호 없애주기
    floating = float(floating) * 0.01
    print("유동비율: ",floating)
    
     #액면가
    price_f = df1.iloc[2][1]
    price_f = price_f.replace('원', '') # 5,000원 -> 5,000
    price_f = price_f.replace(',', '') # 5,000 -> 5000
    price_f = int(price_f)
    print("액면가: ", price_f)

    # 기준시점 시가총액( 기준시점주가 * 발행주식수 * 유동비율)
    marketcap_1 = price1 * outstanding * floating 

    print("시가총액: ",marketcap_1)
# Out:
# --------------------------------------------------
# 회사이름:  SK이노베이션
# 발행 주식수:  92465564.0
# 유동비율:  0.5917
# 액면가:  5000
# 시가총액:  8042645510163.6
# --------------------------------------------------
# 회사이름:  S-Oil
# 발행 주식수:  112582792.0
# 유동비율:  0.36560000000000004
# 액면가:  2500
# 시가총액:  3482158736689.9204
# --------------------------------------------------
# 회사이름:  롯데케미칼
# 발행 주식수:  42775419.0
# 유동비율:  0.4479
# 액면가:  5000
# 시가총액:  6998554717595.148
# --------------------------------------------------
# 회사이름:  GS
# 발행 주식수:  92915378.0
# 유동비율:  0.4769
# 액면가:  5000
# 시가총액:  2406105966613.26
# --------------------------------------------------
# 회사이름:  애경케미칼
# 발행 주식수:  48648709.0
# 유동비율:  0.3264
# 액면가:  500
# 시가총액:  203250414305.28003
# --------------------------------------------------
# 회사이름:  이수화학
# 발행 주식수:  22450795.0
# 유동비율:  0.6914
# 액면가:  5000
# 시가총액:  235584673845.351
# --------------------------------------------------
# 회사이름:  한국쉘석유
# 발행 주식수:  1300000.0
# 유동비율:  0.4615
# 액면가:  5000
# 시가총액:  262178150000.0
# --------------------------------------------------
# 회사이름:  KPX케미칼
# 발행 주식수:  4840000.0
# 유동비율:  0.3385
# 액면가:  5000
# 시가총액:  98628068000.0
# --------------------------------------------------
# 회사이름:  한국석유
# 발행 주식수:  12694120.0
# 유동비율:  0.46049999999999996
# 액면가:  500
# 시가총액:  30870836775.059998
# --------------------------------------------------
# 회사이름:  극동유화
# 발행 주식수:  34869420.0
# 유동비율:  0.5574
# 액면가:  500
# 시가총액:  62487430286.22
# --------------------------------------------------
# 회사이름:  미창석유
# 발행 주식수:  1739672.0
# 유동비율:  0.4673
# 액면가:  5000
# 시가총액:  76010705843.6
# --------------------------------------------------
# 회사이름:  중앙에너비스
# 발행 주식수:  6227130.0
# 유동비율:  0.2132
# 액면가:  500
# 시가총액:  8098507107.6
# --------------------------------------------------
# 회사이름:  흥구석유
# 발행 주식수:  15000000.0
# 유동비율:  0.6272
# 액면가:  100
# 시가총액:  32551680000.0

# %%
# 하나의 기업 주가 데이터
code = '078930'
df = fdr.DataReader(code,'2017-02-10', '2022-02-10')
df
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2017-02-10  51500  54000  51400  53800  400745  0.056974
# 2017-02-13  54000  54800  53800  54200  211255  0.007435
# 2017-02-14  54500  54900  53500  54900  222260  0.012915
# 2017-02-15  54900  55700  54800  55700  245667  0.014572
# 2017-02-16  55700  55700  54900  55000  118048 -0.012567
# ...           ...    ...    ...    ...     ...       ...
# 2022-02-04  39500  40150  39500  39950  147872  0.015248
# 2022-02-07  39950  40100  39400  39950  152386  0.000000
# 2022-02-08  40350  40550  40000  40350  157222  0.010013
# 2022-02-09  40500  40900  40300  40900  213298  0.013631
# 2022-02-10  40900  41350  40650  41000  283013  0.002445
#
# [1228 rows x 6 columns]

# %%
#주가 딕셔너리에 넣기-> 유가,개별 주식간 비교에 사용

price_history = dict()

for code in codes:
    df = fdr.DataReader(code,'2017-02-10', '2022-02-10')
    price_history[code]= df['Close']   # 회사코드: [과거주가 리스트] 

df_history = pd.DataFrame(price_history)
df_history
# Out:
#             096770  010950  011170  078930  161000  005950  002960  025000
# Date
# 2017-02-10  156000   84000  387670   53800   11200   15675  424500   63900  \
# 2017-02-13  157500   85900  385765   54200   11500   16037  427000   64800
# 2017-02-14  155500   86300  379098   54900   11600   16083  426500   64600
# 2017-02-15  157000   87100  378621   55700   11350   15992  423500   65300
# 2017-02-16  158000   87000  372430   55000   11900   15947  420500   65300
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2022-02-04  228000   92500  190501   39950    9950   13050  249500   51400
# 2022-02-07  226500   90900  193835   39950    9820   12900  247500   51700
# 2022-02-08  213500   89000  200026   40350    9730   12700  245000   51900
# 2022-02-09  215500   88000  208123   40900   10300   13450  247000   52200
# 2022-02-10  209500   88500  208123   41000   10250   13350  248000   52200
#
#             004090  014530  003650  000440  024060
# Date
# 2017-02-10    5592    3420   90800    6390    3105
# 2017-02-13    5540    3385   91000    6330    3095
# 2017-02-14    5644    3465   91000    6380    3090
# 2017-02-15    5773    3525   90300    6280    3130
# 2017-02-16    5851    3475   90200    6400    3130
# ...            ...     ...     ...     ...     ...
# 2022-02-04   17750    4045   74100   20300    8050
# 2022-02-07   18350    4120   74600   22150    8150
# 2022-02-08   17800    4030   74900   22150    7910
# 2022-02-09   16400    3970   76000   20300    7510
# 2022-02-10   15900    3925   75700   19900    7440
#
# [1228 rows x 13 columns]

# %% [markdown]
# ## Oil index 함수

# %%
# Oil 지수 구하기 

start_date =  "2017-01-02" 
end_date = "2023-01-02" 

driver = webdriver.Chrome()
marketcap = dict()

for code in codes:
    
    df = fdr.DataReader(code,start_date, end_date)
    company_name = krx_lst[krx_lst['Code']==code]['Name'].iloc[0]
    print(company_name, code)
    
    #기준시점 시가 총액
    price1 = df.loc[start_date]['Close']
    
    url1 = 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd={}'.format(code)
    driver.get(url1)
    time.sleep(0.5)
    html1 = driver.page_source
    df1 = pd.read_html(html1)[1]
   
    # 발행 주식수
    outstanding = df1.iloc[6][1].split('/')[0]
    outstanding = outstanding.replace('주','') # 1,231,000주 -> 1,231,000
    outstanding = outstanding.replace(',', '') # 1,231,000 -> 1231000
    outstanding =  float(outstanding)
    print("발행 주식수: ",outstanding)
    
    # 유동비율 
    floating = df1.iloc[6][1].split('/')[1]
    floating = floating.replace('%', '')  # %기호 없애주기
    floating = float(floating)*0.01
    print("유동비율: ",floating)
    
     #액면가
    price_f = df1.iloc[2][1]
    price_f = price_f.replace('원', '') # 5,000원 -> 5,000
    price_f = price_f.replace(',', '') # 5,000 -> 5000
    price_f = int(price_f)
    print("액면가: ", price_f)
    print('-'* 50)
    
    ## 지수 구하기
    
    # 기업들의 주가 데이터프레임: df_p
    df_p = df.copy()
    
    #비교시점의 시가총액(비교시점주가 * 발행주식수 * 유동비율)
    
    if price_f == 5000:     #액면금액이 5000원
        pass
    elif price_f == 2500:   #액면금액이 2500원
        df_p['Close'] = df_p['Close']/2
        
    elif price_f == 500:    #액면금액이 500원
        df_p['Close'] = df_p['Close']/10
        
    elif price_f == 100:    #액면금액이 100원
        df_p['Close'] = df_p['Close']/50
        
   
    marketcap[code] = df_p['Close'] * outstanding * floating   # 딕셔너리에 추가

    
df_marketcap = pd.DataFrame(marketcap)
df_marketcap['total'] = df_marketcap.sum(axis=1)

# 기준시점(시작일) 시가총액( 기준시점주가 * 발행주식수 * 유동비율)

marketcap_initial = df_marketcap['total'].iloc[0]

# 지수 = (각기업시가총액합 / 시작일의 각 기업시가총액합) * 100
df_marketcap['Oil_index'] = (df_marketcap['total']/ marketcap_initial) * 100

df_marketcap
# Out:
# SK이노베이션 096770
# 발행 주식수:  92465564.0
# 유동비율:  0.5917
# 액면가:  5000
# --------------------------------------------------
# S-Oil 010950
# 발행 주식수:  112582792.0
# 유동비율:  0.36560000000000004
# 액면가:  2500
# --------------------------------------------------
# 롯데케미칼 011170
# 발행 주식수:  42775419.0
# 유동비율:  0.4479
# 액면가:  5000
# --------------------------------------------------
# GS 078930
# 발행 주식수:  92915378.0
# 유동비율:  0.4769
# 액면가:  5000
# --------------------------------------------------
# 애경케미칼 161000
# 발행 주식수:  48648709.0
# 유동비율:  0.3264
# 액면가:  500
# --------------------------------------------------
# 이수화학 005950
# 발행 주식수:  22450795.0
# 유동비율:  0.6914
# 액면가:  5000
# --------------------------------------------------
# 한국쉘석유 002960
# 발행 주식수:  1300000.0
# 유동비율:  0.4615
# 액면가:  5000
# --------------------------------------------------
# KPX케미칼 025000
# 발행 주식수:  4840000.0
# 유동비율:  0.3385
# 액면가:  5000
# --------------------------------------------------
# 한국석유 004090
# 발행 주식수:  12694120.0
# 유동비율:  0.46049999999999996
# 액면가:  500
# --------------------------------------------------
# 극동유화 014530
# 발행 주식수:  34869420.0
# 유동비율:  0.5574
# 액면가:  500
# --------------------------------------------------
# 미창석유 003650
# 발행 주식수:  1739672.0
# 유동비율:  0.4673
# 액면가:  5000
# --------------------------------------------------
# 중앙에너비스 000440
# 발행 주식수:  6227130.0
# 유동비율:  0.2132
# 액면가:  500
# --------------------------------------------------
# 흥구석유 024060
# 발행 주식수:  15000000.0
# 유동비율:  0.6272
# 액면가:  100
# --------------------------------------------------
#                   096770        010950        011170        078930
# Date
# 2017-01-02  8.042646e+12  1.741079e+12  6.998555e+12  2.406106e+12  \
# 2017-01-03  8.480341e+12  1.790472e+12  7.035053e+12  2.419399e+12
# 2017-01-04  8.535052e+12  1.788414e+12  6.816064e+12  2.375088e+12
# 2017-01-05  8.425629e+12  1.774008e+12  6.788686e+12  2.357363e+12
# 2017-01-06  8.589764e+12  1.790472e+12  6.743068e+12  2.383950e+12
# ...                  ...           ...           ...           ...
#     for code in company_codes:

#         df = fdr.DataReader(code,start_date,end_date)

#         #기준시점 시가 총액
#         price1 = df.loc[start_date]['Close']

#         url1 = 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd={}'.format(code)
#         driver.get(url1)
#         time.sleep(0.5)
#         html1 = driver.page_source
#         df1 = pd.read_html(html1)[1]

#         # 발행 주식수
#         outstanding = df1.iloc[6][1].split('/')[0]
#         outstanding = outstanding.replace('주','') # 1,231,000주 -> 1,231,000
#         outstanding = outstanding.replace(',', '') # 1,231,000 -> 1231000
#         outstanding =  float(outstanding)
#         print("발행 주식수: ",outstanding)

#         # 유동비율 
#         floating = df1.iloc[6][1].split('/')[1]
#         floating = floating.replace('%', '')  # %기호 없애주기
#         floating = float(floating)
#         print("유동비율: ",floating)

#          #액면가
#         price_f = df1.iloc[2][1]
#         price_f = price_f.replace('원', '') # 5,000원 -> 5,000
#         price_f = price_f.replace(',', '') # 5,000 -> 5000
#         price_f = int(price_f)
#         print("액면가: ", price_f)
#         print('-'* 50)

#         ## 지수 구하기
#         df_p = df.copy()
        
#         #비교시점의 시가총액(비교시점주가 * 발행주식수 * 유동비율)

#         if price_f == 5000:     #액면금액이 5000원
#             pass
#         elif price_f == 2500:   #액면금액이 2500원
#             df_p['Close_adj'] = df['Close']/2

#         elif price_f == 500:    #액면금액이 500원
#             df_p['Close'] = df_p['Close']/10

#         elif price_f == 100:    #액면금액이 100원
#             df_p['Close'] = df_p['Close']/50


#         marketcap[code] = df_p['Close'] * outstanding * floating   # 딕셔너리에 추가


#     df_marketcap = pd.DataFrame(marketcap)
#     df_marketcap['total'] = df_marketcap.sum(axis=1)

#     # 기준시점(start_date) 시가총액( 기준시점주가 * 발행주식수 * 유동비율)

#     marketcap_std = df_marketcap['total'].iloc[0]

#     # 지수 = (각기업시가총액합 / start_date의 각 기업시가총액합) * 100
#     df_marketcap["Oil_index"] = (df_marketcap['total']/ marketcap_std) * 100

#     return df_marketcap

# %% [markdown]
# ## 시각화

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# x축 index값 못 읽음: reset_index 사용
df1_marketcap = df_marketcap.reset_index()
sns.lineplot(df1_marketcap, x='Date', y='Oil_index')
# Out:
# <Axes: xlabel='Date', ylabel='Oil_index'>

# %% [markdown]
# # 두바이유
# selenium을 써서 investing.com 데이터를 가져올 수도 있으나 추후 모델 배포시 <br>
# selenium이 작동 안할 가능성 높은 관계로 request 사용하여 시도

# %%
# investing.com 두바이유
# selenium 사용안하고 페이지 수를 넘길 수 없으므로 불가
import requests
url = "https://kr.investing.com/commodities/dubai-crude-oil-platts-futures-historical-data"
requests.get(url)
# Out:
# <Response [403]>

# %%
import urllib.request
url_naver = "https://finance.naver.com/marketindex/worldDailyQuote.naver?marketindexCd=OIL_DU&fdtc=2&page=1"
response = urllib.request.urlopen(url_naver)
html = response.read()
df_dubai = pd.read_html(html)[0]
df_dubai
# Out:
#            날짜   파실 때  보내실 때   받으실 때
# 0  2023.05.30  72.08   3.43  -4.54%
# 1  2023.05.26  75.51   0.85  +1.13%
# 2  2023.05.25  74.66   2.12  -2.76%
# 3  2023.05.24  76.78   1.56  +2.07%
# 4  2023.05.23  74.99   0.22  +0.29%
# 5  2023.05.22  74.77   0.16  +0.21%
# 6  2023.05.19  74.61   0.15  -0.19%

# %% [markdown]
# ## 데이터 수집
# 2017년 1월 1일 데이터까지 수집

# %%
import urllib.request
from dateutil import relativedelta 

df_dubai = pd.DataFrame()
# 시작 날짜는 직접 확인해야함(없는 날짜 존재)
oil_start_date = "2017-01-05"
page = 1
while True:
    print("페이지수: ",page, end=" ")
    url_naver = f"https://finance.naver.com/marketindex/worldDailyQuote.naver?marketindexCd=OIL_DU&fdtc=2&page={page}"
    response = urllib.request.urlopen(url_naver)
    html = response.read()
    df_tmp = pd.read_html(html)[0]
    df_tmp['날짜'] = pd.to_datetime(df_tmp['날짜']).dt.date
    print("테이블 시작 날짜: ",df_tmp['날짜'].iloc[0])
    
    df_dubai = pd.concat([df_dubai,df_tmp],axis=0)
    
    # 원하는 날짜 들어있다면 break
    oil_start_date = pd.to_datetime(oil_start_date).date()
    
    if oil_start_date in df_tmp['날짜'].to_list():
        break
        
    # 페이지 넘기기
    page +=1
    
df_dubai
# Out:
# 페이지수:  1 테이블 시작 날짜:  2023-05-30
# 페이지수:  2 테이블 시작 날짜:  2023-05-18
# 페이지수:  3 테이블 시작 날짜:  2023-05-09
# 페이지수:  4 테이블 시작 날짜:  2023-04-28
# 페이지수:  5 테이블 시작 날짜:  2023-04-19
# 페이지수:  6 테이블 시작 날짜:  2023-04-10
# 페이지수:  7 테이블 시작 날짜:  2023-03-30
# 페이지수:  8 테이블 시작 날짜:  2023-03-21
# 페이지수:  9 테이블 시작 날짜:  2023-03-10
# 페이지수:  10 테이블 시작 날짜:  2023-03-01
# 페이지수:  11 테이블 시작 날짜:  2023-02-17
# 페이지수:  12 테이블 시작 날짜:  2023-02-08
# 페이지수:  13 테이블 시작 날짜:  2023-01-30
# 페이지수:  14 테이블 시작 날짜:  2023-01-19
# 페이지수:  15 테이블 시작 날짜:  2023-01-09
# 페이지수:  16 테이블 시작 날짜:  2022-12-28
# 페이지수:  17 테이블 시작 날짜:  2022-12-16
# 페이지수:  18 테이블 시작 날짜:  2022-12-07
# 페이지수:  19 테이블 시작 날짜:  2022-11-28
# 페이지수:  20 테이블 시작 날짜:  2022-11-16
# 페이지수:  21 테이블 시작 날짜:  2022-11-07
# 페이지수:  22 테이블 시작 날짜:  2022-10-27
# 페이지수:  23 테이블 시작 날짜:  2022-10-18
# 페이지수:  24 테이블 시작 날짜:  2022-10-07
# 페이지수:  25 테이블 시작 날짜:  2022-09-28
# 페이지수:  26 테이블 시작 날짜:  2022-09-19
# 페이지수:  27 테이블 시작 날짜:  2022-09-08
# 페이지수:  28 테이블 시작 날짜:  2022-08-29
# 페이지수:  29 테이블 시작 날짜:  2022-08-18
# 페이지수:  30 테이블 시작 날짜:  2022-08-09
# 페이지수:  31 테이블 시작 날짜:  2022-07-29
# 페이지수:  32 테이블 시작 날짜:  2022-07-20
df_dubai.columns = ['Date','Oil_price']
df_dubai
# Out:
#           Date  Oil_price
# 0   2023-05-30      72.08
# 1   2023-05-26      75.51
# 2   2023-05-25      74.66
# 3   2023-05-24      76.78
# 4   2023-05-23      74.99
# ..         ...        ...
# 2   2017-01-05      54.76
# 3   2016-12-30      52.09
# 4   2016-12-29      52.12
# 5   2016-12-28      52.09
# 6   2016-12-27      52.09
#
# [1617 rows x 2 columns]

# %%
df_dubai['Date'] = pd.to_datetime(df_dubai['Date'])
df_dubai = df_dubai.set_index('Date')
df_dubai = df_dubai.sort_index()
df_dubai
# Out:
#             Oil_price
# Date
# 2023-05-30      72.08
# 2023-05-26      75.51
# 2023-05-25      74.66
# 2023-05-24      76.78
# 2023-05-23      74.99
# ...               ...
# 2017-01-05      54.76
# 2016-12-30      52.09
# 2016-12-29      52.12
# 2016-12-28      52.09
# 2016-12-27      52.09
#
# [1617 rows x 1 columns]

# %%
# df_dubai.to_csv("duabi_naver_2017.csv")

# %% [markdown]
# # Oil index 와 석유 가격 데이터프레임

# %%
df_marketcap.head()
# Out:
#                   096770        010950        011170        078930
# Date
# 2017-01-02  8.042646e+12  1.741079e+12  6.998555e+12  2.406106e+12  \
# 2017-01-03  8.480341e+12  1.790472e+12  7.035053e+12  2.419399e+12
# 2017-01-04  8.535052e+12  1.788414e+12  6.816064e+12  2.375088e+12
# 2017-01-05  8.425629e+12  1.774008e+12  6.788686e+12  2.357363e+12
# 2017-01-06  8.589764e+12  1.790472e+12  6.743068e+12  2.383950e+12
#
#                   161000        005950        002960        025000
# Date
# 2017-01-02  2.032504e+10  2.355847e+11  2.621782e+11  9.862807e+10  \
# 2017-01-03  1.976928e+10  2.341721e+11  2.618782e+11  1.020686e+11
# 2017-01-04  2.064262e+10  2.341721e+11  2.594784e+11  1.032154e+11
# 2017-01-05  2.056323e+10  2.313626e+11  2.594784e+11  1.035431e+11
# 2017-01-06  2.056323e+10  2.271404e+11  2.597784e+11  1.056729e+11
#
#                   004090        014530        003650        000440
# Date
# 2017-01-02  3.087084e+09  6.248743e+09  7.601071e+10  8.098507e+08  \
# 2017-01-03  3.132680e+09  6.190434e+09  7.519776e+10  8.045402e+08
# 2017-01-04  3.132680e+09  6.073817e+09  7.527905e+10  7.992297e+08
# 2017-01-05  3.102282e+09  6.102971e+09  7.527905e+10  8.164888e+08
# 2017-01-06  3.087084e+09  6.112690e+09  7.495387e+10  7.979021e+08
#
#                  024060         total   Oil_index
# Date
# 2017-01-02  651033600.0  1.989191e+13  100.000000
# 2017-01-03  631276800.0  2.042911e+13  102.700597
# 2017-01-04  631276800.0  2.021804e+13  101.639531
# 2017-01-05  626572800.0  2.004656e+13  100.777458
# 2017-01-06  635040000.0  2.020600e+13  101.578968

# %%
df_dubai.head()
# Out:
#             Oil_price
# Date
# 2023-05-30      72.08
# 2023-05-26      75.51
# 2023-05-25      74.66
# 2023-05-24      76.78
# 2023-05-23      74.99

# %% [markdown]
# ## index + oil_price 데이터프레임
# * 문제상황: 석유가격은 매일매일 나오지 않을때도 있으며 주말에도 가격이 변하지만 주가의 경우 영업일(Businessday)에만 변화
# * 해결: 일일 데이터를 만들고 영업일(Businessday)기준으로

# %%
df_marketcap.index
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-
00:00:00, 2017-03-08 00:00:00, 2017-03-09 00:00:00, 2017-03-10 00:00:00, 2017-03-11 00:00:00, 2017-03-12 00:00:00, 2017-03-13 00:00:00, 2017-03-14 00:00:00, 2017-03-15 00:00:00, 2017-03-16 00:00:00, 2017-03-17 00:00:00, 2017-03-18 00:00:00, 2017-03-19 00:00:00, 2017-03-20 00:00:00, 2017-03-21 00:00:00, 2017-03-22 00:00:00, 2017-03-23 00:00:00, 2017-03-24 00:00:00, 2017-03-25 00:00:00, 2017-03-26 00:00:00, 2017-03-27 00:00:00, 2017-03-28 00:00:00, 2017-03-29 00:00:00, 2017-03-30 00:00:00, 2017-03-31 00:00:00, 2017-04-01 00:00:00, 2017-04-02 00:00:00, 2017-04-03 00:00:00, 2017-04-04 00:00:00, 2017-04-05 00:00:00, 2017-04-06 00:00:00, 2017-04-07 00:00:00, 2017-04-08 00:00:00, 2017-04-09 00:00:00, 2017-04-10 00:00:00, 2017-04-11 00:00:00, ...]
#
# [2192 rows x 0 columns]

# %% [markdown]
# ## Oil_index,두바이유(Oil_price) 합치기

# %%
df_total = df_daily.merge(df_marketcap[['Oil_index']], right_index=True,left_index=True ,how='left')
df_total = df_total.merge(df_dubai, right_index=True, left_index=True, how='left')
df_total
# Out:
#              Oil_index  Oil_price
# 2017-01-02  100.000000        NaN
# 2017-01-03  102.700597        NaN
# 2017-01-04  101.639531        NaN
# 2017-01-05  100.777458      54.76
# 2017-01-06  101.578968      54.81
# ...                ...        ...
# 2022-12-29   80.932329      78.68
# 2022-12-30         NaN      81.06
# 2022-12-31         NaN        NaN
# 2023-01-01         NaN        NaN
# 2023-01-02   80.549087        NaN
#
# [2192 rows x 2 columns]

# %% [markdown]
# ## Nan값 채우기
# * 석유가격의 경우 불규칙한 일데이터, 주가의 경우 영업일 일데이터이기 때문에 시간 간격을 맞춰줘야 함
# * 시도1: 단순 fillna()함수를 이용한 전날가격으로 채워주기
# * 시도2: 예측할 데이터 기준으로 맞춰주기

# %%
# 첫번째 시도
# 주말 공휴일 등 없는 날짜 전날 가격으로 채워주기 -> granger test에서 유의미한 결과가 나오지 않음(p-value 모두 0)
df_total = df_total.fillna(method='ffill')
df_total = df_total.fillna(method='bfill')
df_total
# Out:
#              Oil_index  Oil_price
# 2017-01-02  100.000000      54.76
# 2017-01-03  102.700597      54.76
# 2017-01-04  101.639531      54.76
# 2017-01-05  100.777458      54.76
# 2017-01-06  101.578968      54.81
# ...                ...        ...
# 2022-12-29   80.932329      78.68
# 2022-12-30   80.932329      81.06
# 2022-12-31   80.932329      81.06
# 2023-01-01   80.932329      81.06
# 2023-01-02   80.549087      81.06
#
# [2192 rows x 2 columns]

# %%
# 두번째 시도

# %% [markdown]
# # 시각화 및 transform

# %% [markdown]
# ## 시각화

# %%
fig,ax = plt.subplots(figsize=(10,5))
df_total.plot(ax=ax, title='Oil index & Oil price')
# Out:
# <Axes: title={'center': 'Oil index & Oil price'}>

# %% [markdown]
# ## 정상 테스트(ADF test)

# %%
from statsmodels.tsa.stattools import adfuller
def adfuller_test(series):
    result = adfuller(series)
    if result[1]>0.05:
        res = "Non-Stationary"
    else:
        res = "Stationary"
        
    print(f"ADF statistic: {result[0]}")
    print(f"p-value: {result[1]}")
    print(f"result: {res}")

# %%
# Oil_index
adfuller_test(df_total['Oil_index'])
# Out:
# ADF statistic: -1.8399731878274652
# p-value: 0.3608043574364316
# result: Non-Stationary

# %%
# 차분
diff_num = 50
df_transformed = df_total.diff(diff_num).dropna()
fig,ax = plt.subplots(figsize=(10,5))
df_transformed.plot(ax=ax, title=f'diff {diff_num} Oil index & Oil price',)
# Out:
# <Axes: title={'center': 'diff 50 Oil index & Oil price'}>

# %%
# 차분 시계열로 다시 정상 테스트
adfuller_test(df_transformed['Oil_index'])
# Out:
# ADF statistic: -5.810275937494702
# p-value: 4.4179906068995013e-07
# result: Stationary

# %%
# Oil_price
adfuller_test(df_transformed['Oil_price'])
# Out:
# ADF statistic: -5.756343693397684
# p-value: 5.807922229033472e-07
# result: Stationary

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
df_transformed[df_transformed.columns] = scaler.fit_transform(df_transformed)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,5), constrained_layout=True)
df_total.plot(ax=axs[0], title="Original Sereis")
df_transformed.plot(ax=axs[1], title='Transformed Series')
# Out:
# <Axes: title={'center': 'Transformed Series'}>

# %%
df_transformed[df_transformed["Oil_price"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Oil_index, Oil_price]
# Index: []

# %% [markdown]
# # 선행성 판단
# * LSTM 계열의 딥러닝을 사용하기 위해선 두 변수의 선행관계가 분명해야함
# * 이를 입증하기 위해 grangercausality 테스트를 진행
# * 수행결과: 유가지수가 두바이유 선물가격을 선행하는 것으로 보여짐

# %%
from statsmodels.tsa.stattools import grangercausalitytests
result = grangercausalitytests(df_transformed[['Oil_index','Oil_price']], maxlag=20)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1526  , p=0.2831  , df_denom=2138, df_num=1
# ssr based chi2 test:   chi2=1.1542  , p=0.2827  , df=1
# likelihood ratio test: chi2=1.1539  , p=0.2827  , df=1
# parameter F test:         F=1.1526  , p=0.2831  , df_denom=2138, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=18.0689 , p=0.0000  , df_denom=2135, df_num=2
# ssr based chi2 test:   chi2=36.2224 , p=0.0000  , df=2
# likelihood ratio test: chi2=35.9192 , p=0.0000  , df=2
# parameter F test:         F=18.0689 , p=0.0000  , df_denom=2135, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=12.9823 , p=0.0000  , df_denom=2132, df_num=3
# ssr based chi2 test:   chi2=39.0747 , p=0.0000  , df=3
# likelihood ratio test: chi2=38.7221 , p=0.0000  , df=3
# parameter F test:         F=12.9823 , p=0.0000  , df_denom=2132, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=9.5400  , p=0.0000  , df_denom=2129, df_num=4
# ssr based chi2 test:   chi2=38.3212 , p=0.0000  , df=4
# likelihood ratio test: chi2=37.9818 , p=0.0000  , df=4
# parameter F test:         F=9.5400  , p=0.0000  , df_denom=2129, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=7.5476  , p=0.0000  , df_denom=2126, df_num=5
# ssr based chi2 test:   chi2=37.9334 , p=0.0000  , df=5
# likelihood ratio test: chi2=37.6007 , p=0.0000  , df=5
# parameter F test:         F=7.5476  , p=0.0000  , df_denom=2126, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=6.3647  , p=0.0000  , df_denom=2123, df_num=6
# ssr based chi2 test:   chi2=38.4223 , p=0.0000  , df=6
# likelihood ratio test: chi2=38.0808 , p=0.0000  , df=6
# parameter F test:         F=6.3647  , p=0.0000  , df_denom=2123, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=5.6534  , p=0.0000  , df_denom=2120, df_num=7
# ssr based chi2 test:   chi2=39.8537 , p=0.0000  , df=7
# likelihood ratio test: chi2=39.4863 , p=0.0000  , df=7
# parameter F test:         F=5.6534  , p=0.0000  , df_denom=2120, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=5.0371  , p=0.0000  , df_denom=2117, df_num=8
# ssr based chi2 test:   chi2=40.6200 , p=0.0000  , df=8
# likelihood ratio test: chi2=40.2382 , p=0.0000  , df=8
# parameter F test:         F=5.0371  , p=0.0000  , df_denom=2117, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=4.5795  , p=0.0000  , df_denom=2114, df_num=9
# ssr based chi2 test:   chi2=41.5857 , p=0.0000  , df=9
# likelihood ratio test: chi2=41.1855 , p=0.0000  , df=9
# parameter F test:         F=4.5795  , p=0.0000  , df_denom=2114, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=4.2034  , p=0.0000  , df_denom=2111, df_num=10
# ssr based chi2 test:   chi2=42.4518 , p=0.0000  , df=10
# likelihood ratio test: chi2=42.0347 , p=0.0000  , df=10
# parameter F test:         F=4.2034  , p=0.0000  , df_denom=2111, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=3.8442  , p=0.0000  , df_denom=2108, df_num=11
# ssr based chi2 test:   chi2=42.7473 , p=0.0000  , df=11
# likelihood ratio test: chi2=42.3242 , p=0.0000  , df=11
# parameter F test:         F=3.8442  , p=0.0000  , df_denom=2108, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=3.6324  , p=0.0000  , df_denom=2105, df_num=12
# ssr based chi2 test:   chi2=44.1063 , p=0.0000  , df=12
# likelihood ratio test: chi2=43.6558 , p=0.0000  , df=12
# parameter F test:         F=3.6324  , p=0.0000  , df_denom=2105, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=3.4643  , p=0.0000  , df_denom=2102, df_num=13
# ssr based chi2 test:   chi2=45.6142 , p=0.0000  , df=13
# likelihood ratio test: chi2=45.1324 , p=0.0000  , df=13
# parameter F test:         F=3.4643  , p=0.0000  , df_denom=2102, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=3.1882  , p=0.0001  , df_denom=2099, df_num=14
# ssr based chi2 test:   chi2=45.2516 , p=0.0000  , df=14
# likelihood ratio test: chi2=44.7772 , p=0.0000  , df=14
# parameter F test:         F=3.1882  , p=0.0001  , df_denom=2099, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=3.0069  , p=0.0001  , df_denom=2096, df_num=15
# ssr based chi2 test:   chi2=45.7701 , p=0.0001  , df=15
# likelihood ratio test: chi2=45.2846 , p=0.0001  , df=15
# parameter F test:         F=3.0069  , p=0.0001  , df_denom=2096, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.7904  , p=0.0002  , df_denom=2093, df_num=16
# ssr based chi2 test:   chi2=45.3506 , p=0.0001  , df=16
# likelihood ratio test: chi2=44.8737 , p=0.0001  , df=16
# parameter F test:         F=2.7904  , p=0.0002  , df_denom=2093, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.6323  , p=0.0003  , df_denom=2090, df_num=17
# ssr based chi2 test:   chi2=45.4979 , p=0.0002  , df=17
# likelihood ratio test: chi2=45.0177 , p=0.0002  , df=17
# parameter F test:         F=2.6323  , p=0.0003  , df_denom=2090, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.6805  , p=0.0002  , df_denom=2087, df_num=18
# ssr based chi2 test:   chi2=49.1044 , p=0.0001  , df=18
# likelihood ratio test: chi2=48.5454 , p=0.0001  , df=18
# parameter F test:         F=2.6805  , p=0.0002  , df_denom=2087, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=2.5583  , p=0.0002  , df_denom=2084, df_num=19
# ssr based chi2 test:   chi2=49.5167 , p=0.0002  , df=19
# likelihood ratio test: chi2=48.9480 , p=0.0002  , df=19
# parameter F test:         F=2.5583  , p=0.0002  , df_denom=2084, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=2.5774  , p=0.0002  , df_denom=2081, df_num=20
# ssr based chi2 test:   chi2=52.5630 , p=0.0001  , df=20
# likelihood ratio test: chi2=51.9225 , p=0.0001  , df=20
# parameter F test:         F=2.5774  , p=0.0002  , df_denom=2081, df_num=20

# %%
from statsmodels.tsa.stattools import grangercausalitytests
result = grangercausalitytests(df_transformed[['Oil_price','Oil_index']], maxlag=30)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.4433 , p=0.0012  , df_denom=2138, df_num=1
# ssr based chi2 test:   chi2=10.4579 , p=0.0012  , df=1
# likelihood ratio test: chi2=10.4324 , p=0.0012  , df=1
# parameter F test:         F=10.4433 , p=0.0012  , df_denom=2138, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3287  , p=0.0049  , df_denom=2135, df_num=2
# ssr based chi2 test:   chi2=10.6824 , p=0.0048  , df=2
# likelihood ratio test: chi2=10.6558 , p=0.0049  , df=2
# parameter F test:         F=5.3287  , p=0.0049  , df_denom=2135, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.3317  , p=0.0047  , df_denom=2132, df_num=3
# ssr based chi2 test:   chi2=13.0376 , p=0.0046  , df=3
# likelihood ratio test: chi2=12.9981 , p=0.0046  , df=3
# parameter F test:         F=4.3317  , p=0.0047  , df_denom=2132, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.0364  , p=0.0029  , df_denom=2129, df_num=4
# ssr based chi2 test:   chi2=16.2138 , p=0.0027  , df=4
# likelihood ratio test: chi2=16.1527 , p=0.0028  , df=4
# parameter F test:         F=4.0364  , p=0.0029  , df_denom=2129, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2568  , p=0.0062  , df_denom=2126, df_num=5
# ssr based chi2 test:   chi2=16.3685 , p=0.0059  , df=5
# likelihood ratio test: chi2=16.3061 , p=0.0060  , df=5
# parameter F test:         F=3.2568  , p=0.0062  , df_denom=2126, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7391  , p=0.0118  , df_denom=2123, df_num=6
# ssr based chi2 test:   chi2=16.5351 , p=0.0112  , df=6
# likelihood ratio test: chi2=16.4714 , p=0.0114  , df=6
# parameter F test:         F=2.7391  , p=0.0118  , df_denom=2123, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.1339  , p=0.0002  , df_denom=2120, df_num=7
# ssr based chi2 test:   chi2=29.1421 , p=0.0001  , df=7
# likelihood ratio test: chi2=28.9450 , p=0.0001  , df=7
# parameter F test:         F=4.1339  , p=0.0002  , df_denom=2120, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.8530  , p=0.0002  , df_denom=2117, df_num=8
# ssr based chi2 test:   chi2=31.0715 , p=0.0001  , df=8
# likelihood ratio test: chi2=30.8475 , p=0.0001  , df=8
# parameter F test:         F=3.8530  , p=0.0002  , df_denom=2117, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.5689  , p=0.0002  , df_denom=2114, df_num=9
# ssr based chi2 test:   chi2=32.4092 , p=0.0002  , df=9
# likelihood ratio test: chi2=32.1654 , p=0.0002  , df=9
# parameter F test:         F=3.5689  , p=0.0002  , df_denom=2114, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.2107  , p=0.0004  , df_denom=2111, df_num=10
# ssr based chi2 test:   chi2=32.4263 , p=0.0003  , df=10
# likelihood ratio test: chi2=32.1821 , p=0.0004  , df=10
# parameter F test:         F=3.2107  , p=0.0004  , df_denom=2111, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.9983  , p=0.0006  , df_denom=2108, df_num=11
# ssr based chi2 test:   chi2=33.3409 , p=0.0005  , df=11
# likelihood ratio test: chi2=33.0828 , p=0.0005  , df=11
# parameter F test:         F=2.9983  , p=0.0006  , df_denom=2108, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.7362  , p=0.0011  , df_denom=2105, df_num=12
# ssr based chi2 test:   chi2=33.2243 , p=0.0009  , df=12
# likelihood ratio test: chi2=32.9679 , p=0.0010  , df=12
# parameter F test:         F=2.7362  , p=0.0011  , df_denom=2105, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.5238  , p=0.0019  , df_denom=2102, df_num=13
# ssr based chi2 test:   chi2=33.2302 , p=0.0016  , df=13
# likelihood ratio test: chi2=32.9735 , p=0.0017  , df=13
# parameter F test:         F=2.5238  , p=0.0019  , df_denom=2102, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.2786  , p=0.0043  , df_denom=2099, df_num=14
# ssr based chi2 test:   chi2=32.3408 , p=0.0036  , df=14
# likelihood ratio test: chi2=32.0975 , p=0.0039  , df=14
# parameter F test:         F=2.2786  , p=0.0043  , df_denom=2099, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.1395  , p=0.0065  , df_denom=2096, df_num=15
# ssr based chi2 test:   chi2=32.5672 , p=0.0054  , df=15
# likelihood ratio test: chi2=32.3204 , p=0.0058  , df=15
# parameter F test:         F=2.1395  , p=0.0065  , df_denom=2096, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.0572  , p=0.0079  , df_denom=2093, df_num=16
# ssr based chi2 test:   chi2=33.4335 , p=0.0065  , df=16
# likelihood ratio test: chi2=33.1733 , p=0.0070  , df=16
# parameter F test:         F=2.0572  , p=0.0079  , df_denom=2093, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.1196  , p=0.0048  , df_denom=2090, df_num=17
# ssr based chi2 test:   chi2=36.6370 , p=0.0038  , df=17
# likelihood ratio test: chi2=36.3247 , p=0.0041  , df=17
# parameter F test:         F=2.1196  , p=0.0048  , df_denom=2090, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.0312  , p=0.0063  , df_denom=2087, df_num=18
# ssr based chi2 test:   chi2=37.2090 , p=0.0049  , df=18
# likelihood ratio test: chi2=36.8868 , p=0.0054  , df=18
# parameter F test:         F=2.0312  , p=0.0063  , df_denom=2087, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=2.0857  , p=0.0039  , df_denom=2084, df_num=19
# ssr based chi2 test:   chi2=40.3692 , p=0.0029  , df=19
# likelihood ratio test: chi2=39.9902 , p=0.0033  , df=19
# parameter F test:         F=2.0857  , p=0.0039  , df_denom=2084, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.9665  , p=0.0064  , df_denom=2081, df_num=20
# ssr based chi2 test:   chi2=40.1059 , p=0.0048  , df=20
# likelihood ratio test: chi2=39.7316 , p=0.0054  , df=20
# parameter F test:         F=1.9665  , p=0.0064  , df_denom=2081, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.7968  , p=0.0145  , df_denom=2078, df_num=21
# ssr based chi2 test:   chi2=38.5126 , p=0.0112  , df=21
# likelihood ratio test: chi2=38.1671 , p=0.0123  , df=21
# parameter F test:         F=1.7968  , p=0.0145  , df_denom=2078, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.7415  , p=0.0176  , df_denom=2075, df_num=22
# ssr based chi2 test:   chi2=39.1440 , p=0.0136  , df=22
# likelihood ratio test: chi2=38.7870 , p=0.0149  , df=22
# parameter F test:         F=1.7415  , p=0.0176  , df_denom=2075, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.7461  , p=0.0155  , df_denom=2072, df_num=23
# ssr based chi2 test:   chi2=41.0715 , p=0.0116  , df=23
# likelihood ratio test: chi2=40.6786 , p=0.0129  , df=23
# parameter F test:         F=1.7461  , p=0.0155  , df_denom=2072, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.7126  , p=0.0170  , df_denom=2069, df_num=24
# ssr based chi2 test:   chi2=42.0753 , p=0.0127  , df=24
# likelihood ratio test: chi2=41.6628 , p=0.0141  , df=24
# parameter F test:         F=1.7126  , p=0.0170  , df_denom=2069, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.6678  , p=0.0203  , df_denom=2066, df_num=25
# ssr based chi2 test:   chi2=42.7234 , p=0.0150  , df=25
# likelihood ratio test: chi2=42.2980 , p=0.0167  , df=25
# parameter F test:         F=1.6678  , p=0.0203  , df_denom=2066, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.6112  , p=0.0263  , df_denom=2063, df_num=26
# ssr based chi2 test:   chi2=42.9662 , p=0.0195  , df=26
# likelihood ratio test: chi2=42.5358 , p=0.0216  , df=26
# parameter F test:         F=1.6112  , p=0.0263  , df_denom=2063, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.5957  , p=0.0268  , df_denom=2060, df_num=27
# ssr based chi2 test:   chi2=44.2349 , p=0.0196  , df=27
# likelihood ratio test: chi2=43.7786 , p=0.0218  , df=27
# parameter F test:         F=1.5957  , p=0.0268  , df_denom=2060, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.6594  , p=0.0165  , df_denom=2057, df_num=28
# ssr based chi2 test:   chi2=47.7517 , p=0.0114  , df=28
# likelihood ratio test: chi2=47.2203 , p=0.0130  , df=28
# parameter F test:         F=1.6594  , p=0.0165  , df_denom=2057, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.7753  , p=0.0067  , df_denom=2054, df_num=29
# ssr based chi2 test:   chi2=52.9630 , p=0.0042  , df=29
# likelihood ratio test: chi2=52.3101 , p=0.0050  , df=29
# parameter F test:         F=1.7753  , p=0.0067  , df_denom=2054, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.6536  , p=0.0145  , df_denom=2051, df_num=30
# ssr based chi2 test:   chi2=51.0848 , p=0.0095  , df=30
# likelihood ratio test: chi2=50.4767 , p=0.0111  , df=30
# parameter F test:         F=1.6536  , p=0.0145  , df_denom=2051, df_num=30

# %% [markdown]
# # 모델링

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Conv1D, Dropout, RepeatVector, TimeDistributed, MaxPooling1D,Flatten

# %% [markdown]
# ## CNN-LSTM(single step)
# 기존 LSTM모델에 각 부분을 요약해주는 CNN 의 기능을 더해 시계열의 부분별 분포를 고려해 준 모델

# %%
def create_rnn_data(data, window_size):
    y = data[window_size:]
    X = np.stack([data[i:i+window_size] for i in range(len(data)-window_size)])
    return X,y

# %%
window_size = 10
X,y = create_rnn_data(df_total, window_size=10)

# %%
print(X.shape)
print(y.shape)
# Out:
# (2182, 10, 2)
# (2182, 2)

# %%
test_size = 30
train_size = X.shape[0]-test_size

# %%
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
y_test
# Out:
#             Oil_index  Oil_price
# 2022-12-04  87.517484      80.10
# 2022-12-05  87.294446      77.52
# 2022-12-06  86.391300      75.12
# 2022-12-07  84.725001      73.88
# 2022-12-08  84.968166      73.45
# 2022-12-09  85.683173      73.71
# 2022-12-10  85.683173      73.71
# 2022-12-11  85.683173      73.71
# 2022-12-12  86.171009      75.13
# 2022-12-13  86.738043      76.62
# 2022-12-14  86.369006      77.67
# 2022-12-15  84.969045      76.90
# 2022-12-16  85.303707      75.89
# 2022-12-17  85.303707      75.89
# 2022-12-18  85.303707      75.89
# 2022-12-19  84.887792      76.31
# 2022-12-20  83.616041      76.40
# 2022-12-21  83.870589      77.10
# 2022-12-22  85.449432      76.87
# 2022-12-23  84.191225      80.11
# 2022-12-24  84.191225      80.11
# 2022-12-25  84.191225      80.11
# 2022-12-26  84.805476      80.11
# 2022-12-27  84.806385      80.29
# 2022-12-28  82.758685      79.45
# 2022-12-29  80.932329      78.68
# 2022-12-30  80.932329      81.06
# 2022-12-31  80.932329      81.06
# 2023-01-01  80.932329      81.06
# 2023-01-02  80.549087      81.06

# %%
# 딥러닝 변수 정하기
verbose, epochs, batch_size = 0, 100, 16
n_timesteps, n_feature, n_outputs = X_train.shape[1], X_train.shape[2],y_train.shape[1]

# %%
# CNN-LSTM
rnn = Sequential([
    Conv1D(filters=256, kernel_size=2, activation='relu',
           input_shape=(window_size,n_feature), padding='same'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    RepeatVector(n_outputs),
    LSTM(units=200,activation='tanh', return_sequences=True),
    Dropout(0.3),
    LSTM(units=200,activation='tanh', return_sequences=True),
    TimeDistributed(Dense(100,activation='relu')),
    TimeDistributed(Dense(1))
])     

rnn.compile(loss='mse', optimizer='adam')
rnn.summary()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[130], line 2
#       1 # CNN-LSTM
# ----> 2 rnn = Sequential([
#       3     Conv1D(filters=256, kernel_size=2, activation='relu',
#       4            input_shape=(window_size,n_feature), padding='same'),
#       5     MaxPooling1D(pool_size=2),
#       6     Flatten(),
#       7     RepeatVector(n_outputs),
#       8     LSTM(units=200,activation='tanh', return_sequences=True),
#       9     Dropout(0.3),
#      10     LSTM(units=200,activation='tanh', return_sequences=True),
#      11     TimeDistributed(Dense(100,activation='relu')),
#      12     TimeDistributed(Dense(1))
#      13 ])
#      15 rnn.compile(loss='mse', optimizer='adam')
#      16 rnn.summary()
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\training\tracking\base.py:522, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     520 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521 try:
# --> 522   result = method(self, *args, **kwargs)
#     523 finally:
#     524   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\engine\sequential.py:141, in Sequential.__init__(self, layers, name)
#     139   layers = [layers]
#     140 for layer in layers:
# --> 141   self.add(layer)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\training\tracking\base.py:522, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     520 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521 try:
# --> 522   result = method(self, *args, **kwargs)
#     523 finally:
#     524   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\engine\sequential.py:228, in Sequential.add(self, layer)
#     223     self._has_explicit_input_shape = True
#     225 elif self.outputs:
#     226   # If the model is being built continuously on top of an input layer:
#     227   # refresh its output.
# --> 228   output_tensor = layer(self.outputs[0])
#     229   if len(nest.flatten(output_tensor)) != 1:
#     230     raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:668, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     662 inputs, initial_state, constants = _standardize_args(inputs,
#     663                                                      initial_state,
#     664                                                      constants,
#     665                                                      self._num_constants)
#     667 if initial_state is None and constants is None:
# --> 668   return super(RNN, self).__call__(inputs, **kwargs)
#     670 # If any of `initial_state` or `constants` are specified and are Keras
#     671 # tensors, then add them to the inputs and temporarily modify the
#     672 # input_spec to include them.
#     674 additional_inputs = []
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:969, in Layer.__call__(self, *args, **kwargs)
#     963 # Functional Model construction mode is invoked when `Layer`s are called on
#     964 # symbolic `KerasTensor`s, i.e.:
#     965 # >> inputs = tf.keras.Input(10)
#     966 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#     967 # >> model = tf.keras.Model(inputs, outputs)
#     968 if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 969   return self._functional_construction_call(inputs, args, kwargs,
#     970                                             input_list)
#     972 # Maintains info about the `Layer.call` stack.
#     973 call_context = base_layer_utils.call_context()
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1107, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    1102     training_arg_passed_by_framework = True
#    1104 with call_context.enter(
#    1105     layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1106   # Check input assumptions set after layer building, e.g. input shape.
# -> 1107   outputs = self._keras_tensor_symbolic_call(
#    1108       inputs, input_masks, args, kwargs)
#    1110   if outputs is None:
#    1111     raise ValueError('A layer\'s `call` method should return a '
#    1112                      'Tensor or a list of Tensors, not None '
#    1113                      '(layer: ' + self.name + ').')
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:840, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     838   return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     839 else:
# --> 840   return self._infer_output_signature(inputs, args, kwargs, input_masks)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:880, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#     878     self._maybe_build(inputs)
#     879     inputs = self._maybe_cast_inputs(inputs)
# --> 880     outputs = call_fn(inputs, *args, **kwargs)
#     882   self._handle_activity_regularization(inputs, outputs)
#     883 self._set_mask_metadata(inputs, outputs, input_masks,
#     884                         build_graph=False)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py:1153, in LSTM.call(self, inputs, mask, training, initial_state)
#    1150 self._validate_args_if_ragged(is_ragged_input, mask)
#    1152 # LSTM does not support constants. Ignore it during process.
# -> 1153 inputs, initial_state, _ = self._process_inputs(inputs, initial_state, None)
#    1155 if isinstance(mask, list):
#    1156   mask = mask[0]
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:868, in RNN._process_inputs(self, inputs, initial_state, constants)
#     866     initial_state = self.states
#     867 elif initial_state is None:
# --> 868   initial_state = self.get_initial_state(inputs)
#     870 if len(initial_state) != len(self.states):
#     871   raise ValueError('Layer has ' + str(len(self.states)) +
#     872                    ' states but was passed ' + str(len(initial_state)) +
#     873                    ' initial states.')
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:650, in RNN.get_initial_state(self, inputs)
#     648 dtype = inputs.dtype
#     649 if get_initial_state_fn:
# --> 650   init_state = get_initial_state_fn(
#     651       inputs=None, batch_size=batch_size, dtype=dtype)
#     652 else:
#     653   init_state = _generate_zero_filled_state(batch_size, self.cell.state_size,
#     654                                            dtype)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:2516, in LSTMCell.get_initial_state(self, inputs, batch_size, dtype)
#    2515 def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
# -> 2516   return list(_generate_zero_filled_state_for_cell(
#    2517       self, inputs, batch_size, dtype))
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:2998, in _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype)
#    2996   batch_size = array_ops.shape(inputs)[0]
#    2997   dtype = inputs.dtype
# -> 2998 return _generate_zero_filled_state(batch_size, cell.state_size, dtype)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:3014, in _generate_zero_filled_state(batch_size_tensor, state_size, dtype)
#    3011   return array_ops.zeros(init_state_size, dtype=dtype)
#    3013 if nest.is_nested(state_size):
# -> 3014   return nest.map_structure(create_zeros, state_size)
#    3015 else:
#    3016   return create_zeros(state_size)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\util\nest.py:867, in map_structure(func, *structure, **kwargs)
#     863 flat_structure = (flatten(s, expand_composites) for s in structure)
#     864 entries = zip(*flat_structure)
#     866 return pack_sequence_as(
# --> 867     structure[0], [func(*x) for x in entries],
#     868     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\util\nest.py:867, in <listcomp>(.0)
#     863 flat_structure = (flatten(s, expand_composites) for s in structure)
#     864 entries = zip(*flat_structure)
#     866 return pack_sequence_as(
# --> 867     structure[0], [func(*x) for x in entries],
#     868     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\keras\layers\recurrent.py:3011, in _generate_zero_filled_state.<locals>.create_zeros(unnested_state_size)
#    3009 flat_dims = tensor_shape.TensorShape(unnested_state_size).as_list()
#    3010 init_state_size = [batch_size_tensor] + flat_dims
# -> 3011 return array_ops.zeros(init_state_size, dtype=dtype)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\ops\array_ops.py:2911, in _tag_zeros_tensor.<locals>.wrapped(*args, **kwargs)
#    2910 def wrapped(*args, **kwargs):
# -> 2911   tensor = fun(*args, **kwargs)
#    2912   tensor._is_zeros_tensor = True
#    2913   return tensor
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\ops\array_ops.py:2960, in zeros(shape, dtype, name)
#    2956 try:
#    2957   if not context.executing_eagerly():
#    2958     # Create a constant if it won't be very big. Otherwise create a fill
#    2959     # op to prevent serialized GraphDefs from becoming too large.
# -> 2960     output = _constant_if_small(zero, shape, dtype, name)
#    2961     if output is not None:
#    2962       return output
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\ops\array_ops.py:2896, in _constant_if_small(value, shape, dtype, name)
#    2894 def _constant_if_small(value, shape, dtype, name):
#    2895   try:
# -> 2896     if np.prod(shape) < 1000:
#    2897       return constant(value, shape=shape, dtype=dtype, name=name)
#    2898   except TypeError:
#    2899     # Happens when shape is a Tensor, list with Tensor elements, etc.
#
# File <__array_function__ internals>:180, in prod(*args, **kwargs)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\numpy\core\fromnumeric.py:3045, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2927 @array_function_dispatch(_prod_dispatcher)
#    2928 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2929          initial=np._NoValue, where=np._NoValue):
#    2930     """
#    2931     Return the product of array elements over a given axis.
#    2932
#    (...)
#    3043     10
#    3044     """
# -> 3045     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3046                           keepdims=keepdims, initial=initial, where=where)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\numpy\core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File ~\anaconda3\envs\tf2.5_py3.8\lib\site-packages\tensorflow\python\framework\ops.py:867, in Tensor.__array__(self)
#     866 def __array__(self):
# --> 867   raise NotImplementedError(
#     868       "Cannot convert a symbolic Tensor ({}) to a numpy array."
#     869       " This error may indicate that you're trying to pass a Tensor to"
#     870       " a NumPy call, which is not supported".format(self.name))
#
# NotImplementedError: Cannot convert a symbolic Tensor (lstm/strided_slice:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %%
# stationary 로 바꾸세요

# %% [markdown]
# ## seq2seq(multistep)
